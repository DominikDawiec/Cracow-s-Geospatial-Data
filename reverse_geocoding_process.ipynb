# %%
# Import libraries
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim
import folium
from tqdm import tqdm
from PIL import Image

# %%
# Read the excel files for each type of location
airport = pd.read_excel('uncleaned_data/airport.xlsx')
chapels = pd.read_excel('uncleaned_data/chapels.xlsx')
cinema = pd.read_excel('uncleaned_data/cinemas.xlsx')
city_center = pd.read_excel('uncleaned_data/city_center.xlsx')
custody_penitentiary = pd.read_excel('uncleaned_data/custodies_penitentiaries.xlsx')
district_court = pd.read_excel('uncleaned_data/district_court.xlsx')
emergency_room = pd.read_excel('uncleaned_data/emergency_rooms.xlsx')
football_stadium = pd.read_excel('uncleaned_data/football_stadiums.xlsx')
grocery_store = pd.read_excel('uncleaned_data/grocery_stores.xlsx')
gym = pd.read_excel('uncleaned_data/gyms.xlsx')
high_school = pd.read_excel('uncleaned_data/high_schools.xlsx')
horseback_riding_center = pd.read_excel('uncleaned_data/horseback_riding_center.xlsx')
hospital = pd.read_excel('uncleaned_data/hospitals.xlsx')
indoor_swimming_pool = pd.read_excel('uncleaned_data/indoor_swimming_pool.xlsx')
municipal_police_department = pd.read_excel('uncleaned_data/municipal_police_departments.xlsx')
museum = pd.read_excel('uncleaned_data/museums.xlsx')
natural_swimming_pool = pd.read_excel('uncleaned_data/natural_swimming_pools.xlsx')
orlik_soccer_field = pd.read_excel('uncleaned_data/orlik_soccer_fields.xlsx')
park = pd.read_excel('uncleaned_data/parks.xlsx')
pharmacy = pd.read_excel('uncleaned_data/pharmacies.xlsx')
police_station = pd.read_excel('uncleaned_data/police_stations.xlsx')
primary_care_units = pd.read_excel('uncleaned_data/primary_care_units.xlsx')
primary_school = pd.read_excel('uncleaned_data/primary_schools.xlsx')
river = pd.read_excel('uncleaned_data/river.xlsx')
roman_catholic_church = pd.read_excel('uncleaned_data/roman_catholic_church.xlsx')
rope_park = pd.read_excel('uncleaned_data/rope_parks.xlsx')
rossmann = pd.read_excel('uncleaned_data/rossmanns.xlsx')
shopping_center = pd.read_excel('uncleaned_data/shopping_centers.xlsx')
street_workout = pd.read_excel('uncleaned_data/street_workouts.xlsx')
tax_administration_chamber = pd.read_excel('uncleaned_data/tax_administration_chambers.xlsx')
tax_office = pd.read_excel('uncleaned_data/tax_offices.xlsx')
technical_college = pd.read_excel('uncleaned_data/technical_colleges.xlsx')
vocational_school = pd.read_excel('uncleaned_data/vocational_schools.xlsx')
zabka = pd.read_excel('uncleaned_data/zabka_shops.xlsx')

# %%
def get_lat_long(dataframe):
    # Initialize the geolocator using the Nominatim class from the geopy library
    geolocator = Nominatim(user_agent="http")

    # Initialize the progress bar
    pbar = tqdm(total=len(dataframe))

    # Iterate through each row in the dataframe
    for index, row in dataframe.iterrows():
        # Get the address from the current row
        address = row['Address']
    
        # Geocode the address using the geolocator
        location = geolocator.geocode(address)
    
        # Try to update the latitude column in the dataframe
        try:
            dataframe.loc[index, 'Latitude'] = location.latitude
        except:
            # If an error occurs, set the latitude to "N/A" and print a message
            dataframe.loc[index, 'Latitude'] = "N/A"
            print(f"{address} could not be reached for the latitude")

        # Try to update the longitude column in the dataframe
        try:
            dataframe.loc[index, 'Longitude'] = location.longitude
        except:
            # If an error occurs, set the longitude to "N/A" and print a message
            dataframe.loc[index, 'Longitude'] = "N/A"
            print(f"{address} could not be reached for the longitude")

        # Update the progress bar
        pbar.update(1)

    # Close the progress bar
    pbar.close()

# %%
def plot_map(df):
    
    # Create a map centered at the mean coordinates of the DataFrame
    lat_mean = df['Latitude'].mean()
    lon_mean = df['Longitude'].mean()
    m = folium.Map(location=[lat_mean, lon_mean], zoom_start=12)

    # Add markers for each coordinate in the DataFrame
    for index, row in df.iterrows():
        # Extract the information to be displayed in the popup
        info = row['Name'] 
        
        # Extract the coordinates and convert them to a tuple
        location = (row['Latitude'], row['Longitude'])
        tiles='Cloudmade'
        
        # Create a marker with a custom icon and the information to be displayed in the popup
        marker = folium.Marker(location=location, icon=folium.Icon(icon='info-sign'), popup=info)
        #icons: https://fontawesome.com/search?q=location&o=r
        
        # Add the marker to the map
        marker.add_to(m)

    # Display the map
    return m

# %%
plot_map(city_center)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0443e52e9ada3c5f71dc64c87dffa588 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0443e52e9ada3c5f71dc64c87dffa588&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0443e52e9ada3c5f71dc64c87dffa588 = L.map(
#                 &quot;map_0443e52e9ada3c5f71dc64c87dffa588&quot;,
#                 {
#                     center: [50.061695, 19.937333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_372f676d6d1bf9019d53371f59efe713 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0443e52e9ada3c5f71dc64c87dffa588);
#
#
#             var marker_012bfb4b7293436bee5e8ea3f3129cae = L.marker(
#                 [50.061695, 19.937333],
#                 {}
#             ).addTo(map_0443e52e9ada3c5f71dc64c87dffa588);
#
#
#             var icon_eefa2e9e2c3beed1dfc5519c3d8faa35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_012bfb4b7293436bee5e8ea3f3129cae.setIcon(icon_eefa2e9e2c3beed1dfc5519c3d8faa35);
#
#
#         var popup_f2cb9626eb10f9c8b91401b5fc95d78e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6305b511c5b581de680a3e93cfb783b9 = $(`&lt;div id=&quot;html_6305b511c5b581de680a3e93cfb783b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rynek Główny&lt;/div&gt;`)[0];
#                 popup_f2cb9626eb10f9c8b91401b5fc95d78e.setContent(html_6305b511c5b581de680a3e93cfb783b9);
#
#
#
#         marker_012bfb4b7293436bee5e8ea3f3129cae.bindPopup(popup_f2cb9626eb10f9c8b91401b5fc95d78e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_map(airport)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_962d1e046ba3fe0330c779ae22eb764e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_962d1e046ba3fe0330c779ae22eb764e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_962d1e046ba3fe0330c779ae22eb764e = L.map(
#                 &quot;map_962d1e046ba3fe0330c779ae22eb764e&quot;,
#                 {
#                     center: [50.077024, 19.787667],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcae48eba04070ef83d11ba63f086a49 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_962d1e046ba3fe0330c779ae22eb764e);
#
#
#             var marker_16f09f86b2ba78525a1933d3e959062f = L.marker(
#                 [50.077024, 19.787667],
#                 {}
#             ).addTo(map_962d1e046ba3fe0330c779ae22eb764e);
#
#
#             var icon_4cf9c84d9340d12c073787faea5626b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16f09f86b2ba78525a1933d3e959062f.setIcon(icon_4cf9c84d9340d12c073787faea5626b0);
#
#
#         var popup_68b62f87eefe7c54a67ef540ebced14c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_674a86219b31fe35dc9848ff5641c618 = $(`&lt;div id=&quot;html_674a86219b31fe35dc9848ff5641c618&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kapitana Mieczysława Medweckiego 1, 32-083 Balice&lt;/div&gt;`)[0];
#                 popup_68b62f87eefe7c54a67ef540ebced14c.setContent(html_674a86219b31fe35dc9848ff5641c618);
#
#
#
#         marker_16f09f86b2ba78525a1933d3e959062f.bindPopup(popup_68b62f87eefe7c54a67ef540ebced14c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plot_map(park)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1057a2043d23cbda16d0a4e5cbb41e47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1057a2043d23cbda16d0a4e5cbb41e47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1057a2043d23cbda16d0a4e5cbb41e47 = L.map(
#                 &quot;map_1057a2043d23cbda16d0a4e5cbb41e47&quot;,
#                 {
#                     center: [50.06441262500001, 19.979831145833334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08abf7a0c73b032973ad056e3b247b0a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1057a2043d23cbda16d0a4e5cbb41e47);
#
#
#             var marker_1352f29a23ef4cbcca605251b3c0ff90 = L.marker(
#                 [50.066105, 19.950011],
#                 {}
#             ).addTo(map_1057a2043d23cbda16d0a4e5cbb41e47);
#
#
#             var icon_aa8976a55d0a663dd0ebc50a55c7229c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1352f29a23ef4cbcca605251b3c0ff90.setIcon(icon_aa8976a55d0a663dd0ebc50a55c7229c);
#
#
#         var popup_f5c72d5c31fd5a2214a991e3c2bf482a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bdf4f7dbab052d764a820885729936d = $(`&lt;div id=&quot;html_0bdf4f7dbab052d764a820885729936d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Park Strzelecki&lt;/div&gt;`)[0];
#                 popup_f5c72d5c31fd5a2214a991e3c2bf482a.setContent(html_0bdf4f7dbab052d764a820885729936d);
#
#
#
#         marker_1352f29a23ef4cbcca605251b3c0ff90.bindPopup(popup_f5c72d5c31fd5a2214a991e3c2bf482a)
#         ;
#
#
#
#
#             var marker_ace22af4ad5a098555c885b647ff5090 = L.marker(
#                 [50.056066, 19.979021],
#                 {}
#             ).addTo(map_1057a2043d23cbda16d0a4e5cbb41e47);
#
#
#             var icon_a3237d9e2866d3f11f7186c334ac64e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ace22af4ad5a098555c885b647ff5090.setIcon(icon_a3237d9e2866d3f11f7186c334ac64e8);
#
#
#         var popup_3cae82a699e4efb85cec21c3799dfa2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9fc1cc8134708a4ec6e9ce1ba231281 = $(`&lt;div id=&quot;html_d9fc1cc8134708a4ec6e9ce1ba231281&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Park Dąbie&lt;/div&gt;`)[0];
#                 popup_3cae82a699e4efb85cec21c3799dfa2b.setContent(html_d9fc1cc8134708a4ec6e9ce1ba231281);
#
#
#
#         marker_ace22af4ad5a098555c885b647ff5090.bindPopup(popup_3cae82a699e4efb85cec21c3799dfa2b)
#         ;
#
#
#
#
#             var marker_6867874bcfeffe52003dd653b992cf08 = L.marker(
#                 [50.086614, 19.966201],
#                 {}
#             ).addTo(map_1057a2043d23cbda16d0a4e5cbb41e47);
#
#
#             var icon_531f33495924131a16dcb834e0de46bb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6867874bcfeffe52003dd653b992cf08.setIcon(icon_531f33495924131a16dcb834e0de46bb);
#
#
#         var popup_5cbe15f7452e9c9a4b072d435b6f0f37 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f7731c60adf3ea749763ca3f971d972 = $(`&lt;div id=&quot;html_7f7731c60adf3ea749763ca3f971d972&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Park Zaczarowanej Dorożki&lt;/div&gt;`)[0];
#                 popup_5cbe15f7452e9c9a4b072d435b6f0f37.setContent(html_7f7731c60adf3ea749763ca3f971d972);
#
#
#
#         marker_6867874bcfeffe52003dd653b992cf08.bindPopup(popup_5cbe15f7452e9c9a4b072d435b6f0f37)
#         ;
#
#
#
#
#             var marker_ae72a95bf7d689a422f8beb902cb1411 = L.marker(
#                 [50.109164, 19.954721],
#                 {}
#             ).addTo(map_1057a2043d23cbda16d0a4e5cbb41e47);
#
#
#             var icon_8f98f759e627cb19857231a4155dc11c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;

# %%
plot_map(river)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47e9d3be9109a49a0e243d3a8c3ec248 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47e9d3be9109a49a0e243d3a8c3ec248&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47e9d3be9109a49a0e243d3a8c3ec248 = L.map(
#                 &quot;map_47e9d3be9109a49a0e243d3a8c3ec248&quot;,
#                 {
#                     center: [50.048879953703654, 19.95442875000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee228a6845d3ec33bf427a07e6e770a9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47e9d3be9109a49a0e243d3a8c3ec248);
#
#
#             var marker_df081430ed79fce7e3fff3dd30941b39 = L.marker(
#                 [50.033409, 19.825329],
#                 {}
#             ).addTo(map_47e9d3be9109a49a0e243d3a8c3ec248);
#
#
#             var icon_14294d2497b62c25b3b4c56bf4037083 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_df081430ed79fce7e3fff3dd30941b39.setIcon(icon_14294d2497b62c25b3b4c56bf4037083);
#
#
#         var popup_c9b06938d1e7b830e8d4966e3c384a66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3fc53293024a3adef44f9bc03430cd7c = $(`&lt;div id=&quot;html_3fc53293024a3adef44f9bc03430cd7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vistula&lt;/div&gt;`)[0];
#                 popup_c9b06938d1e7b830e8d4966e3c384a66.setContent(html_3fc53293024a3adef44f9bc03430cd7c);
#
#
#
#         marker_df081430ed79fce7e3fff3dd30941b39.bindPopup(popup_c9b06938d1e7b830e8d4966e3c384a66)
#         ;
#
#
#
#
#             var marker_c35a40b67594e3d19af52b7043e7498f = L.marker(
#                 [50.037507, 19.838975],
#                 {}
#             ).addTo(map_47e9d3be9109a49a0e243d3a8c3ec248);
#
#
#             var icon_e31ea8a4c70bda983ae36ab2c7256115 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c35a40b67594e3d19af52b7043e7498f.setIcon(icon_e31ea8a4c70bda983ae36ab2c7256115);
#
#
#         var popup_16d1860fcd1fdb252a5e6c93e46be276 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a072dbb07a4f90b9d81de64ee4560425 = $(`&lt;div id=&quot;html_a072dbb07a4f90b9d81de64ee4560425&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vistula&lt;/div&gt;`)[0];
#                 popup_16d1860fcd1fdb252a5e6c93e46be276.setContent(html_a072dbb07a4f90b9d81de64ee4560425);
#
#
#
#         marker_c35a40b67594e3d19af52b7043e7498f.bindPopup(popup_16d1860fcd1fdb252a5e6c93e46be276)
#         ;
#
#
#
#
#             var marker_3148d35aea2adbce67c6a812e19fbf65 = L.marker(
#                 [50.042197, 19.847561],
#                 {}
#             ).addTo(map_47e9d3be9109a49a0e243d3a8c3ec248);
#
#
#             var icon_fdc450c6346fe014b94c9e9c90631e05 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3148d35aea2adbce67c6a812e19fbf65.setIcon(icon_fdc450c6346fe014b94c9e9c90631e05);
#
#
#         var popup_5b1993c317eb443688ed018ae38c8059 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f69eb36322bf74e284aff9c5bea752f = $(`&lt;div id=&quot;html_1f69eb36322bf74e284aff9c5bea752f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vistula&lt;/div&gt;`)[0];
#                 popup_5b1993c317eb443688ed018ae38c8059.setContent(html_1f69eb36322bf74e284aff9c5bea752f);
#
#
#
#         marker_3148d35aea2adbce67c6a812e19fbf65.bindPopup(popup_5b1993c317eb443688ed018ae38c8059)
#         ;
#
#
#
#
#             var marker_4d5a308f7445ac8400f054ecd94cba93 = L.marker(
#                 [50.043936, 19.858744],
#                 {}
#             ).addTo(map_47e9d3be9109a49a0e243d3a8c3ec248);
#
#
#             var icon_4d4709de1410ca23488ca89d2897e0f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;inf

# %%
get_lat_long(chapels)
plot_map(chapels)
# Out:
# 100%|██████████| 28/28 [00:13<00:00,  2.01it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aab2e3fc2cfb5ac403d9d124b90047b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aab2e3fc2cfb5ac403d9d124b90047b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aab2e3fc2cfb5ac403d9d124b90047b4 = L.map(
#                 &quot;map_aab2e3fc2cfb5ac403d9d124b90047b4&quot;,
#                 {
#                     center: [50.04716154999999, 19.951844768854947],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d63568f8867ad9b66234299c5428f7c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aab2e3fc2cfb5ac403d9d124b90047b4);
#
#
#             var marker_9703ea0bb486c8e5d47443e9b340b383 = L.marker(
#                 [50.0729087, 19.937061299283272],
#                 {}
#             ).addTo(map_aab2e3fc2cfb5ac403d9d124b90047b4);
#
#
#             var icon_59e322131d343a79b5fddbd7271d8d8e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9703ea0bb486c8e5d47443e9b340b383.setIcon(icon_59e322131d343a79b5fddbd7271d8d8e);
#
#
#         var popup_2bfd098ec0a83389ea2356e0d07a421d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_176a8321be4c36d868c29555170302da = $(`&lt;div id=&quot;html_176a8321be4c36d868c29555170302da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kaplica św. Anny&lt;/div&gt;`)[0];
#                 popup_2bfd098ec0a83389ea2356e0d07a421d.setContent(html_176a8321be4c36d868c29555170302da);
#
#
#
#         marker_9703ea0bb486c8e5d47443e9b340b383.bindPopup(popup_2bfd098ec0a83389ea2356e0d07a421d)
#         ;
#
#
#
#
#             var marker_1c94677d7ad2384dfbb534c817d087a4 = L.marker(
#                 [50.0549448, 19.894567082721714],
#                 {}
#             ).addTo(map_aab2e3fc2cfb5ac403d9d124b90047b4);
#
#
#             var icon_ab4f5645e0ef24e22964b81e4e524ee2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1c94677d7ad2384dfbb534c817d087a4.setIcon(icon_ab4f5645e0ef24e22964b81e4e524ee2);
#
#
#         var popup_04615d39cecad2ce3c37724fda35a2b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78874296fa3c7665fb0d805c73549301 = $(`&lt;div id=&quot;html_78874296fa3c7665fb0d805c73549301&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kaplica bł. Bronisławy&lt;/div&gt;`)[0];
#                 popup_04615d39cecad2ce3c37724fda35a2b4.setContent(html_78874296fa3c7665fb0d805c73549301);
#
#
#
#         marker_1c94677d7ad2384dfbb534c817d087a4.bindPopup(popup_04615d39cecad2ce3c37724fda35a2b4)
#         ;
#
#
#
#
#             var marker_9f444f651ff17fd67a623b772e5396af = L.marker(
#                 [50.101260249999996, 19.983209055595218],
#                 {}
#             ).addTo(map_aab2e3fc2cfb5ac403d9d124b90047b4);
#
#
#             var icon_4c55249f138462d2e2852ef3798f7c82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9f444f651ff17fd67a623b772e5396af.setIcon(icon_4c55249f138462d2e2852ef3798f7c82);
#
#
#         var popup_2b22ce210d6e9c41fc437d3f5d096b35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b58fc4d28b270e1d1f207a43e3eaea9c = $(`&lt;div id=&quot;html_b58fc4d28b270e1d1f207a43e3eaea9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kaplica Chrystusa Króla&lt;/div&gt;`)[0];
#                 popup_2b22ce210d6e9c41fc437d3f5d096b35.setContent(html_b58fc4d28b270e1d1f207a43e3eaea9c);
#
#
#
#         marker_9f444f651ff17fd67a623b772e5396af.bindPopup(popup_2b22ce210d6e9c41fc437d3f5d096b35)
#         ;
#
#
#
#
#             var marker_11a6b98f74608a0df41d09846044d1c7 = L.marker(
#                 [50.005141, 19.9869266],
#                 {}
#             ).addTo(map_aab2e3fc2cfb5ac403d9d124b90047b4);
#
#
#             var icon_c4f2d7537ed35d9059c9d77b98634682 = L.AwesomeMarkers.icon(

# %%
get_lat_long(cinema)
plot_map(cinema)
# Out:
# 100%|██████████| 11/11 [00:05<00:00,  2.03it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6471b5a107369c6aec61bb8593bce1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6471b5a107369c6aec61bb8593bce1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6471b5a107369c6aec61bb8593bce1f = L.map(
#                 &quot;map_b6471b5a107369c6aec61bb8593bce1f&quot;,
#                 {
#                     center: [50.057178681818186, 19.949893950358383],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64fe96893f15f2ec74fabae9c5bd16c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b6471b5a107369c6aec61bb8593bce1f);
#
#
#             var marker_2dc7da2589b829acb2d8e5dc67a2e2a2 = L.marker(
#                 [50.02797685, 19.950720762557644],
#                 {}
#             ).addTo(map_b6471b5a107369c6aec61bb8593bce1f);
#
#
#             var icon_ee0197b506b1a6b308b96cd07ed80d0c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2dc7da2589b829acb2d8e5dc67a2e2a2.setIcon(icon_ee0197b506b1a6b308b96cd07ed80d0c);
#
#
#         var popup_89f86e770e76a68b1fe61ab210e24872 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6f89e54072a701c3aa0242223189ce5 = $(`&lt;div id=&quot;html_e6f89e54072a701c3aa0242223189ce5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cinema City Bonarka&lt;/div&gt;`)[0];
#                 popup_89f86e770e76a68b1fe61ab210e24872.setContent(html_e6f89e54072a701c3aa0242223189ce5);
#
#
#
#         marker_2dc7da2589b829acb2d8e5dc67a2e2a2.bindPopup(popup_89f86e770e76a68b1fe61ab210e24872)
#         ;
#
#
#
#
#             var marker_559a336b7eea45597b3effc7ea78f527 = L.marker(
#                 [50.0534233, 19.9543024],
#                 {}
#             ).addTo(map_b6471b5a107369c6aec61bb8593bce1f);
#
#
#             var icon_e60b0de279665b9ec11104a8d4d99e90 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_559a336b7eea45597b3effc7ea78f527.setIcon(icon_e60b0de279665b9ec11104a8d4d99e90);
#
#
#         var popup_cedee5484ec3b0c56478f63ef16c0eb7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a83456d62cc4ad1003a8c47f857ea3f4 = $(`&lt;div id=&quot;html_a83456d62cc4ad1003a8c47f857ea3f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cinema City Galeria Kazimierz&lt;/div&gt;`)[0];
#                 popup_cedee5484ec3b0c56478f63ef16c0eb7.setContent(html_a83456d62cc4ad1003a8c47f857ea3f4);
#
#
#
#         marker_559a336b7eea45597b3effc7ea78f527.bindPopup(popup_cedee5484ec3b0c56478f63ef16c0eb7)
#         ;
#
#
#
#
#             var marker_f2d090998f2b78787d1882d5570c1ab6 = L.marker(
#                 [50.0165169, 19.930620111368132],
#                 {}
#             ).addTo(map_b6471b5a107369c6aec61bb8593bce1f);
#
#
#             var icon_64b8786a4aebd2658a7dbfb1aaf15ea9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f2d090998f2b78787d1882d5570c1ab6.setIcon(icon_64b8786a4aebd2658a7dbfb1aaf15ea9);
#
#
#         var popup_0bb51791137aaa3daed0b5c6520cc9b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40c2fb32bf8dc08475429d7912b63ad9 = $(`&lt;div id=&quot;html_40c2fb32bf8dc08475429d7912b63ad9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cinema City Zakopianka&lt;/div&gt;`)[0];
#                 popup_0bb51791137aaa3daed0b5c6520cc9b0.setContent(html_40c2fb32bf8dc08475429d7912b63ad9);
#
#
#
#         marker_f2d090998f2b78787d1882d5570c1ab6.bindPopup(popup_0bb51791137aaa3daed0b5c6520cc9b0)
#         ;
#
#
#
#
#             var marker_9c332bdecf2f78a771825f2414cbde27 = L.marker(
#                 [50.0582858, 19.924901064413177],
#                 {}
#             ).addTo(map_b6471b5a107369c6aec61bb8593bce1f);
#
#
#             var icon_2dd60bf54dfedfc28f1a00480f114b06 = L.AwesomeMarkers.icon(

# %%
get_lat_long(custody_penitentiary)
plot_map(custody_penitentiary)
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  2.12it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b432a6f3332a9505765365e7fa5de5c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b432a6f3332a9505765365e7fa5de5c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b432a6f3332a9505765365e7fa5de5c7 = L.map(
#                 &quot;map_b432a6f3332a9505765365e7fa5de5c7&quot;,
#                 {
#                     center: [50.0828949, 20.036916367741146],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_414aeee7f2464ebe0965996cbdb867f8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b432a6f3332a9505765365e7fa5de5c7);
#
#
#             var marker_703864bd088e89d3a5711c445e531a6d = L.marker(
#                 [50.0739372, 19.939804835482292],
#                 {}
#             ).addTo(map_b432a6f3332a9505765365e7fa5de5c7);
#
#
#             var icon_30573cde0217fa33328a22bc693a215e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_703864bd088e89d3a5711c445e531a6d.setIcon(icon_30573cde0217fa33328a22bc693a215e);
#
#
#         var popup_16fdf795074bece5f7902f6a51b3253e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59e7f49d2e470c889d51e47b6d81e95e = $(`&lt;div id=&quot;html_59e7f49d2e470c889d51e47b6d81e95e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Custody &amp; Penitentiary&lt;/div&gt;`)[0];
#                 popup_16fdf795074bece5f7902f6a51b3253e.setContent(html_59e7f49d2e470c889d51e47b6d81e95e);
#
#
#
#         marker_703864bd088e89d3a5711c445e531a6d.bindPopup(popup_16fdf795074bece5f7902f6a51b3253e)
#         ;
#
#
#
#
#             var marker_b9a847e412ff116fdc98a53393319050 = L.marker(
#                 [50.0918526, 20.1340279],
#                 {}
#             ).addTo(map_b432a6f3332a9505765365e7fa5de5c7);
#
#
#             var icon_092f17b5ac0a2f84beb0101b9e011923 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b9a847e412ff116fdc98a53393319050.setIcon(icon_092f17b5ac0a2f84beb0101b9e011923);
#
#
#         var popup_c6782862db29d30aad2aab1da243008f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_398a1d8b89168917ab7fe06494fe3cc2 = $(`&lt;div id=&quot;html_398a1d8b89168917ab7fe06494fe3cc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Custody &amp; Penitentiary&lt;/div&gt;`)[0];
#                 popup_c6782862db29d30aad2aab1da243008f.setContent(html_398a1d8b89168917ab7fe06494fe3cc2);
#
#
#
#         marker_b9a847e412ff116fdc98a53393319050.bindPopup(popup_c6782862db29d30aad2aab1da243008f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
get_lat_long(district_court)
plot_map(district_court)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3db4ebe747c390f60a5c0600683e625 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3db4ebe747c390f60a5c0600683e625&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3db4ebe747c390f60a5c0600683e625 = L.map(
#                 &quot;map_d3db4ebe747c390f60a5c0600683e625&quot;,
#                 {
#                     center: [50.0638676, 19.9619939],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4249a13dbe38c98bd6dc69dd0b72044 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d3db4ebe747c390f60a5c0600683e625);
#
#
#             var marker_5a03ac2e1e0cc84ddf14a21f7ed139e2 = L.marker(
#                 [50.0638676, 19.9619939],
#                 {}
#             ).addTo(map_d3db4ebe747c390f60a5c0600683e625);
#
#
#             var icon_df9128c179fcd318530da01c83d3e090 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5a03ac2e1e0cc84ddf14a21f7ed139e2.setIcon(icon_df9128c179fcd318530da01c83d3e090);
#
#
#         var popup_daf45216a119fc5265a7c8e0ec8cdb38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4221a764b1817d599ea2825f41ce08a0 = $(`&lt;div id=&quot;html_4221a764b1817d599ea2825f41ce08a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sąd Okręgowy w Krakowie&lt;/div&gt;`)[0];
#                 popup_daf45216a119fc5265a7c8e0ec8cdb38.setContent(html_4221a764b1817d599ea2825f41ce08a0);
#
#
#
#         marker_5a03ac2e1e0cc84ddf14a21f7ed139e2.bindPopup(popup_daf45216a119fc5265a7c8e0ec8cdb38)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
get_lat_long(emergency_room)
plot_map(emergency_room)
# Out:
# 100%|██████████| 6/6 [00:02<00:00,  2.00it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca743f591ca0640874225cccad3147c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca743f591ca0640874225cccad3147c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca743f591ca0640874225cccad3147c5 = L.map(
#                 &quot;map_ca743f591ca0640874225cccad3147c5&quot;,
#                 {
#                     center: [50.05929255, 19.985608595625017],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_364709fee85870f23de6c1d40ec0689a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ca743f591ca0640874225cccad3147c5);
#
#
#             var marker_567429e189a986062859033a8a5383b7 = L.marker(
#                 [50.0758184, 19.9332395],
#                 {}
#             ).addTo(map_ca743f591ca0640874225cccad3147c5);
#
#
#             var icon_7f5a313024f761c4ebeedd43c68d4327 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_567429e189a986062859033a8a5383b7.setIcon(icon_7f5a313024f761c4ebeedd43c68d4327);
#
#
#         var popup_56d6b759acc13fc0b04d1ec6c5cccaa4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0352e48fc79e112b8aca9cb1ba16e674 = $(`&lt;div id=&quot;html_0352e48fc79e112b8aca9cb1ba16e674&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 Wojskowy Szpital Kliniczny z Polikliniką - Samodzielny Publiczny Zakład Opieki Zdrowotnej w Krakowie&lt;/div&gt;`)[0];
#                 popup_56d6b759acc13fc0b04d1ec6c5cccaa4.setContent(html_0352e48fc79e112b8aca9cb1ba16e674);
#
#
#
#         marker_567429e189a986062859033a8a5383b7.bindPopup(popup_56d6b759acc13fc0b04d1ec6c5cccaa4)
#         ;
#
#
#
#
#             var marker_cb05fbfd5bd4fbe7a0a47bac25795f57 = L.marker(
#                 [50.0085146, 19.9997055737501],
#                 {}
#             ).addTo(map_ca743f591ca0640874225cccad3147c5);
#
#
#             var icon_f67e3a18b47e94a41b3baaa928d5994d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cb05fbfd5bd4fbe7a0a47bac25795f57.setIcon(icon_f67e3a18b47e94a41b3baaa928d5994d);
#
#
#         var popup_680b4f91b10c106502b8fd4fc9e848c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f617a2dd3cd27d3e335d1e0d7687c33 = $(`&lt;div id=&quot;html_7f617a2dd3cd27d3e335d1e0d7687c33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SAMODZIELNY PUBLICZNY ZAKŁAD OPIEKI ZDROWOTNEJ SZPITAL UNIWERSYTECKI W KRAKOWIE&lt;/div&gt;`)[0];
#                 popup_680b4f91b10c106502b8fd4fc9e848c2.setContent(html_7f617a2dd3cd27d3e335d1e0d7687c33);
#
#
#
#         marker_cb05fbfd5bd4fbe7a0a47bac25795f57.bindPopup(popup_680b4f91b10c106502b8fd4fc9e848c2)
#         ;
#
#
#
#
#             var marker_a7e169774d167f1ae8e60fc1f9523b01 = L.marker(
#                 [50.0861205, 19.9382876],
#                 {}
#             ).addTo(map_ca743f591ca0640874225cccad3147c5);
#
#
#             var icon_a86b2d4731c82f40a529a6e75427cdcb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a7e169774d167f1ae8e60fc1f9523b01.setIcon(icon_a86b2d4731c82f40a529a6e75427cdcb);
#
#
#         var popup_8f595d89fb424c4f6fa1224c4b1d09b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3724100f71c80da43bb69f112c5440f8 = $(`&lt;div id=&quot;html_3724100f71c80da43bb69f112c5440f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Szpital Miejski Specjalistyczny im. Gabriela Narutowicza&lt;/div&gt;`)[0];
#                 popup_8f595d89fb424c4f6fa1224c4b1d09b4.setContent(html_3724100f71c80da43bb69f112c5440f8);
#
#
#
#         marker_a7e169774d167f1ae8e60fc1f9523b01.bindPopup(popup_8f595d89fb424c4f6fa1224c4b1d09b4)
#         ;
#
#
#
#
#             var marker_df30dac71721c16d257993c499ed9943 = L.marker(
#                 [50.092785, 20.020044],
#                 {}
#             ).addTo(map_c

# %%
get_lat_long(football_stadium)
plot_map(football_stadium)
# Out:
# 100%|██████████| 24/24 [00:11<00:00,  2.01it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b5b649e85638764c9eddca5e10b222a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b5b649e85638764c9eddca5e10b222a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b5b649e85638764c9eddca5e10b222a = L.map(
#                 &quot;map_4b5b649e85638764c9eddca5e10b222a&quot;,
#                 {
#                     center: [50.04675636041665, 19.963599649628907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a030658ced3aa04d4a1e4a84b230644 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4b5b649e85638764c9eddca5e10b222a);
#
#
#             var marker_4a3f5a3f6785f03d926d672132f3493e = L.marker(
#                 [50.0144002, 19.9186276],
#                 {}
#             ).addTo(map_4b5b649e85638764c9eddca5e10b222a);
#
#
#             var icon_5fe8264fc3c196edf35750525787ad4c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a3f5a3f6785f03d926d672132f3493e.setIcon(icon_5fe8264fc3c196edf35750525787ad4c);
#
#
#         var popup_281955f349cdcd0fc3fd23115dbb3eb0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87380f06204b875f5348c29e683ed2fc = $(`&lt;div id=&quot;html_87380f06204b875f5348c29e683ed2fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Klub Sportowy Borek&lt;/div&gt;`)[0];
#                 popup_281955f349cdcd0fc3fd23115dbb3eb0.setContent(html_87380f06204b875f5348c29e683ed2fc);
#
#
#
#         marker_4a3f5a3f6785f03d926d672132f3493e.bindPopup(popup_281955f349cdcd0fc3fd23115dbb3eb0)
#         ;
#
#
#
#
#             var marker_940dc9ab51bb406f15896ad294d85182 = L.marker(
#                 [50.0940908, 19.9443089],
#                 {}
#             ).addTo(map_4b5b649e85638764c9eddca5e10b222a);
#
#
#             var icon_431fe31e41dc210d177ee7efd3806009 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_940dc9ab51bb406f15896ad294d85182.setIcon(icon_431fe31e41dc210d177ee7efd3806009);
#
#
#         var popup_64adbe0423e7fa9a6f20536051a4e33e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e81f7c05d6d4645abbd1ef9d3d917aa = $(`&lt;div id=&quot;html_6e81f7c05d6d4645abbd1ef9d3d917aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Klub Sportowy Clepardia&lt;/div&gt;`)[0];
#                 popup_64adbe0423e7fa9a6f20536051a4e33e.setContent(html_6e81f7c05d6d4645abbd1ef9d3d917aa);
#
#
#
#         marker_940dc9ab51bb406f15896ad294d85182.bindPopup(popup_64adbe0423e7fa9a6f20536051a4e33e)
#         ;
#
#
#
#
#             var marker_cdb3110a2e041cf7582186a062b3946d = L.marker(
#                 [50.0961391, 20.0745159],
#                 {}
#             ).addTo(map_4b5b649e85638764c9eddca5e10b222a);
#
#
#             var icon_d5aad896b8fbf03a510a53e26689b0fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cdb3110a2e041cf7582186a062b3946d.setIcon(icon_d5aad896b8fbf03a510a53e26689b0fc);
#
#
#         var popup_9072338cdb84e7d8dcc3948e93508ade = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf7f0474beff45d18073f01dd4460710 = $(`&lt;div id=&quot;html_bf7f0474beff45d18073f01dd4460710&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Klub Sportowy Grębałowianka&lt;/div&gt;`)[0];
#                 popup_9072338cdb84e7d8dcc3948e93508ade.setContent(html_bf7f0474beff45d18073f01dd4460710);
#
#
#
#         marker_cdb3110a2e041cf7582186a062b3946d.bindPopup(popup_9072338cdb84e7d8dcc3948e93508ade)
#         ;
#
#
#
#
#             var marker_b2f3e2028b5615c5db07e52f84ef2b58 = L.marker(
#                 [50.0513575, 19.9363066],
#                 {}
#             ).addTo(map_4b5b649e85638764c9eddca5e10b222a);
#
#
#             var icon_fdf31c17f69db90021c325a6f8039507 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quo

# %%
get_lat_long(grocery_store)
plot_map(grocery_store)
# Out:
# 100%|██████████| 125/125 [01:02<00:00,  2.00it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f1a2f949b67234da9ff4912425bb076 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f1a2f949b67234da9ff4912425bb076&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f1a2f949b67234da9ff4912425bb076 = L.map(
#                 &quot;map_2f1a2f949b67234da9ff4912425bb076&quot;,
#                 {
#                     center: [50.059202692799985, 19.958000359005982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4465243a1635355985fc3bede6166072 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2f1a2f949b67234da9ff4912425bb076);
#
#
#             var marker_c0f6b4d9db41fd7fa59e28f01d48709a = L.marker(
#                 [50.0602019, 19.9006433],
#                 {}
#             ).addTo(map_2f1a2f949b67234da9ff4912425bb076);
#
#
#             var icon_38bd77d31d067251f9578e9a51dadad0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c0f6b4d9db41fd7fa59e28f01d48709a.setIcon(icon_38bd77d31d067251f9578e9a51dadad0);
#
#
#         var popup_755928ceb5820e4593d58a1200433dae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b693f951875ce1f95c28379dd96484b = $(`&lt;div id=&quot;html_6b693f951875ce1f95c28379dd96484b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Biedronka&lt;/div&gt;`)[0];
#                 popup_755928ceb5820e4593d58a1200433dae.setContent(html_6b693f951875ce1f95c28379dd96484b);
#
#
#
#         marker_c0f6b4d9db41fd7fa59e28f01d48709a.bindPopup(popup_755928ceb5820e4593d58a1200433dae)
#         ;
#
#
#
#
#             var marker_6ce67fa3c4f8654a08cbfffb83f5e542 = L.marker(
#                 [50.0941957, 19.928031143830992],
#                 {}
#             ).addTo(map_2f1a2f949b67234da9ff4912425bb076);
#
#
#             var icon_113c3d3d70dc2e155e8f928d264c9b1e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6ce67fa3c4f8654a08cbfffb83f5e542.setIcon(icon_113c3d3d70dc2e155e8f928d264c9b1e);
#
#
#         var popup_e24e157cef2fc498f7435ad7f428f7ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4efd97708455d322a8cd64fb405069dc = $(`&lt;div id=&quot;html_4efd97708455d322a8cd64fb405069dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Biedronka&lt;/div&gt;`)[0];
#                 popup_e24e157cef2fc498f7435ad7f428f7ca.setContent(html_4efd97708455d322a8cd64fb405069dc);
#
#
#
#         marker_6ce67fa3c4f8654a08cbfffb83f5e542.bindPopup(popup_e24e157cef2fc498f7435ad7f428f7ca)
#         ;
#
#
#
#
#             var marker_8943d37425cd86de0555d64ccb48d1c1 = L.marker(
#                 [50.0795027, 20.0105048],
#                 {}
#             ).addTo(map_2f1a2f949b67234da9ff4912425bb076);
#
#
#             var icon_7beb47757537ca84e00c9fbbe7284c87 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8943d37425cd86de0555d64ccb48d1c1.setIcon(icon_7beb47757537ca84e00c9fbbe7284c87);
#
#
#         var popup_be028fa434737ddd582eec5cebfb3ff2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48586506ea806067d9c47ce960d2e1ee = $(`&lt;div id=&quot;html_48586506ea806067d9c47ce960d2e1ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Biedronka&lt;/div&gt;`)[0];
#                 popup_be028fa434737ddd582eec5cebfb3ff2.setContent(html_48586506ea806067d9c47ce960d2e1ee);
#
#
#
#         marker_8943d37425cd86de0555d64ccb48d1c1.bindPopup(popup_be028fa434737ddd582eec5cebfb3ff2)
#         ;
#
#
#
#
#             var marker_0dee14d8411bab6e7ade5ce6ad32115d = L.marker(
#                 [50.01676865, 20.01029016458265],
#                 {}
#             ).addTo(map_2f1a2f949b67234da9ff4912425bb076);
#
#
#             var icon_81cc7fa5f282c2a7069d8ca918d58b8b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quo

# %%
get_lat_long(gym)
plot_map(gym)
# Out:
# 100%|██████████| 79/79 [00:39<00:00,  2.01it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3efa2c34a9513aebaa6f643de988b8aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3efa2c34a9513aebaa6f643de988b8aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3efa2c34a9513aebaa6f643de988b8aa = L.map(
#                 &quot;map_3efa2c34a9513aebaa6f643de988b8aa&quot;,
#                 {
#                     center: [50.05476876392404, 19.942414672897282],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3544c4fb14c41b6f532668907834a5a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3efa2c34a9513aebaa6f643de988b8aa);
#
#
#             var marker_c4faa66d458f2554b672dde5f887e075 = L.marker(
#                 [50.07738295, 20.02735897044014],
#                 {}
#             ).addTo(map_3efa2c34a9513aebaa6f643de988b8aa);
#
#
#             var icon_9eb61a7bbeff4cce5ed6fc0aa4f1753e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c4faa66d458f2554b672dde5f887e075.setIcon(icon_9eb61a7bbeff4cce5ed6fc0aa4f1753e);
#
#
#         var popup_d90c380242f74d683e5c3150164c6b56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93f5cd86eeb81de14ea15db58b8ae4ca = $(`&lt;div id=&quot;html_93f5cd86eeb81de14ea15db58b8ae4ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Active Niuton Ośrodek Promocji Zdrowia&lt;/div&gt;`)[0];
#                 popup_d90c380242f74d683e5c3150164c6b56.setContent(html_93f5cd86eeb81de14ea15db58b8ae4ca);
#
#
#
#         marker_c4faa66d458f2554b672dde5f887e075.bindPopup(popup_d90c380242f74d683e5c3150164c6b56)
#         ;
#
#
#
#
#             var marker_6a83814e3294e41a75ecfecfe78d5356 = L.marker(
#                 [50.0528743, 19.9400451],
#                 {}
#             ).addTo(map_3efa2c34a9513aebaa6f643de988b8aa);
#
#
#             var icon_720f44557aafd3a2a6aa8981cd685637 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6a83814e3294e41a75ecfecfe78d5356.setIcon(icon_720f44557aafd3a2a6aa8981cd685637);
#
#
#         var popup_fc9a66f0618723dfc7a0cfaae85281e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3b90d95a9f5a88daa60efb14dea5b59 = $(`&lt;div id=&quot;html_e3b90d95a9f5a88daa60efb14dea5b59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Atlantic Squash &amp; Fitness&lt;/div&gt;`)[0];
#                 popup_fc9a66f0618723dfc7a0cfaae85281e2.setContent(html_e3b90d95a9f5a88daa60efb14dea5b59);
#
#
#
#         marker_6a83814e3294e41a75ecfecfe78d5356.bindPopup(popup_fc9a66f0618723dfc7a0cfaae85281e2)
#         ;
#
#
#
#
#             var marker_3271c1d7b476c738975a618ef1926016 = L.marker(
#                 [50.0613107, 20.0172824],
#                 {}
#             ).addTo(map_3efa2c34a9513aebaa6f643de988b8aa);
#
#
#             var icon_ffe3b94519cd94365ea494d2a742ecc3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3271c1d7b476c738975a618ef1926016.setIcon(icon_ffe3b94519cd94365ea494d2a742ecc3);
#
#
#         var popup_070d3d89ef428fcc1fd7da9b7dbd9bc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c94be6e99a5daae9a7b3266e0557786 = $(`&lt;div id=&quot;html_2c94be6e99a5daae9a7b3266e0557786&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avatar Centrala Ruchu_2&lt;/div&gt;`)[0];
#                 popup_070d3d89ef428fcc1fd7da9b7dbd9bc8.setContent(html_2c94be6e99a5daae9a7b3266e0557786);
#
#
#
#         marker_3271c1d7b476c738975a618ef1926016.bindPopup(popup_070d3d89ef428fcc1fd7da9b7dbd9bc8)
#         ;
#
#
#
#
#             var marker_f5486349a50ac6141b9ca2d6ab4c2510 = L.marker(
#                 [50.06851965, 19.901025398157053],
#                 {}
#             ).addTo(map_3efa2c34a9513aebaa6f643de988b8aa);
#
#
#             var icon_cde24d0e49575f94479294acf0a2b446 = L.AwesomeMarkers.icon(

# %%
get_lat_long(high_school)
plot_map(high_school)
# Out:
# 100%|██████████| 78/78 [00:38<00:00,  2.01it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c84b18566c450c123ecdf5f52c5da168 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c84b18566c450c123ecdf5f52c5da168&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c84b18566c450c123ecdf5f52c5da168 = L.map(
#                 &quot;map_c84b18566c450c123ecdf5f52c5da168&quot;,
#                 {
#                     center: [50.06275126923078, 19.962379207509134],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f93993d71293c05f356b16bc8776432 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c84b18566c450c123ecdf5f52c5da168);
#
#
#             var marker_4c4bb7035fe6add96a3de15674c0a4cb = L.marker(
#                 [50.0571662, 19.93373412653324],
#                 {}
#             ).addTo(map_c84b18566c450c123ecdf5f52c5da168);
#
#
#             var icon_d6158024758aa99117af394b5199a2d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4c4bb7035fe6add96a3de15674c0a4cb.setIcon(icon_d6158024758aa99117af394b5199a2d1);
#
#
#         var popup_d167796c5dd891ce44328593bf0e3477 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74da0d9a0532c737d6e72dfd5ca44556 = $(`&lt;div id=&quot;html_74da0d9a0532c737d6e72dfd5ca44556&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I Liceum Ogólnokształcące im. Bartłomieja Nowodworskiego&lt;/div&gt;`)[0];
#                 popup_d167796c5dd891ce44328593bf0e3477.setContent(html_74da0d9a0532c737d6e72dfd5ca44556);
#
#
#
#         marker_4c4bb7035fe6add96a3de15674c0a4cb.bindPopup(popup_d167796c5dd891ce44328593bf0e3477)
#         ;
#
#
#
#
#             var marker_6d00e2d87a78565a91dfb155efe65d1b = L.marker(
#                 [50.0793196, 20.0348179],
#                 {}
#             ).addTo(map_c84b18566c450c123ecdf5f52c5da168);
#
#
#             var icon_393924ce184638c81e137a0ec4266c3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6d00e2d87a78565a91dfb155efe65d1b.setIcon(icon_393924ce184638c81e137a0ec4266c3a);
#
#
#         var popup_54471d8af879cfcd5a689da7504c9266 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b4676ca58f95f719eb1cb0591d3f0b6 = $(`&lt;div id=&quot;html_2b4676ca58f95f719eb1cb0591d3f0b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I Liceum Ogólnokształcące Sportowe w Krakowie Zespół Szkół Ogólnokształcących Sportowych nr 2&lt;/div&gt;`)[0];
#                 popup_54471d8af879cfcd5a689da7504c9266.setContent(html_2b4676ca58f95f719eb1cb0591d3f0b6);
#
#
#
#         marker_6d00e2d87a78565a91dfb155efe65d1b.bindPopup(popup_54471d8af879cfcd5a689da7504c9266)
#         ;
#
#
#
#
#             var marker_4a08d9fdbfe27639ea9aaaf06d37765b = L.marker(
#                 [50.0682602, 19.931259],
#                 {}
#             ).addTo(map_c84b18566c450c123ecdf5f52c5da168);
#
#
#             var icon_dacf9c843b729d9582070a7c86d390a0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a08d9fdbfe27639ea9aaaf06d37765b.setIcon(icon_dacf9c843b729d9582070a7c86d390a0);
#
#
#         var popup_848c9213fd5b5a35136e9c50c39756e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3355c92436b184d25dd2374473ef045b = $(`&lt;div id=&quot;html_3355c92436b184d25dd2374473ef045b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;II Liceum Ogólnokształcące im. Króla Jana III Sobieskiego&lt;/div&gt;`)[0];
#                 popup_848c9213fd5b5a35136e9c50c39756e7.setContent(html_3355c92436b184d25dd2374473ef045b);
#
#
#
#         marker_4a08d9fdbfe27639ea9aaaf06d37765b.bindPopup(popup_848c9213fd5b5a35136e9c50c39756e7)
#         ;
#
#
#
#
#             var marker_f9a9b27c387b0b50c39839e0b5fa47b8 = L.marker(
#                 [50.0889995, 20.018185814877622],
#                 {}
#             ).addTo(map_c84b18566c450c12

# %%
get_lat_long(horseback_riding_center)
plot_map(horseback_riding_center)
# Out:
# 100%|██████████| 13/13 [00:06<00:00,  2.04it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_958ba3dfe884edf82a97e5e439f4408f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_958ba3dfe884edf82a97e5e439f4408f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_958ba3dfe884edf82a97e5e439f4408f = L.map(
#                 &quot;map_958ba3dfe884edf82a97e5e439f4408f&quot;,
#                 {
#                     center: [50.072903569230775, 19.937908699820586],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16dbcc966e223e4d17e5c3bbda015f12 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_958ba3dfe884edf82a97e5e439f4408f);
#
#
#             var marker_e9c5cb5b6ab29d06b1f0f9d91f0d3f4e = L.marker(
#                 [50.0738223, 19.866874604712187],
#                 {}
#             ).addTo(map_958ba3dfe884edf82a97e5e439f4408f);
#
#
#             var icon_9fbb93f2b6e6c74bfd087e4356bd1a91 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e9c5cb5b6ab29d06b1f0f9d91f0d3f4e.setIcon(icon_9fbb93f2b6e6c74bfd087e4356bd1a91);
#
#
#         var popup_31b576169e37f016e3ac7460800ef145 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_811456bcb3fb882a5930822d04efe36e = $(`&lt;div id=&quot;html_811456bcb3fb882a5930822d04efe36e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Klub Jazdy Konnej CHEVAL&lt;/div&gt;`)[0];
#                 popup_31b576169e37f016e3ac7460800ef145.setContent(html_811456bcb3fb882a5930822d04efe36e);
#
#
#
#         marker_e9c5cb5b6ab29d06b1f0f9d91f0d3f4e.bindPopup(popup_31b576169e37f016e3ac7460800ef145)
#         ;
#
#
#
#
#             var marker_ff2563fd7c6015082c535131d96e62dc = L.marker(
#                 [50.0738223, 19.866874604712187],
#                 {}
#             ).addTo(map_958ba3dfe884edf82a97e5e439f4408f);
#
#
#             var icon_a128ab4d30c41cabbc51a3db89d6f5b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ff2563fd7c6015082c535131d96e62dc.setIcon(icon_a128ab4d30c41cabbc51a3db89d6f5b7);
#
#
#         var popup_53573dbb199d0c75fc77e36436b6f293 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_92bfcc778b99175cce8c07f64a703869 = $(`&lt;div id=&quot;html_92bfcc778b99175cce8c07f64a703869&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Klub Jazdy Konnej &quot;Mustang&quot;&lt;/div&gt;`)[0];
#                 popup_53573dbb199d0c75fc77e36436b6f293.setContent(html_92bfcc778b99175cce8c07f64a703869);
#
#
#
#         marker_ff2563fd7c6015082c535131d96e62dc.bindPopup(popup_53573dbb199d0c75fc77e36436b6f293)
#         ;
#
#
#
#
#             var marker_3c20bf10a44686d9f3aa28c0870e315c = L.marker(
#                 [50.0642114, 19.8705468],
#                 {}
#             ).addTo(map_958ba3dfe884edf82a97e5e439f4408f);
#
#
#             var icon_16e1accf28d960b4923b89dde69af09a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3c20bf10a44686d9f3aa28c0870e315c.setIcon(icon_16e1accf28d960b4923b89dde69af09a);
#
#
#         var popup_2529217003e297bb1d407fa3ccdea179 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8cd8278f0b34809a7cd17c8afc53905 = $(`&lt;div id=&quot;html_c8cd8278f0b34809a7cd17c8afc53905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Klub Jeździecki &quot;Decjusz&quot;&lt;/div&gt;`)[0];
#                 popup_2529217003e297bb1d407fa3ccdea179.setContent(html_c8cd8278f0b34809a7cd17c8afc53905);
#
#
#
#         marker_3c20bf10a44686d9f3aa28c0870e315c.bindPopup(popup_2529217003e297bb1d407fa3ccdea179)
#         ;
#
#
#
#
#             var marker_0066054a0c5657fc62ca260ca672cfb6 = L.marker(
#                 [50.065123400000004, 19.830279872487495],
#                 {}
#             ).addTo(map_958ba3dfe884edf82a97e5e439f4408f);
#
#
#             var icon_3d99bf07025183c25e224cda3730f901 = L.

# %%
get_lat_long(hospital)
plot_map(hospital)
# Out:
# 100%|██████████| 17/17 [00:08<00:00,  2.01it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce5c6f5361452cc8ca90c7ad300f0a4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce5c6f5361452cc8ca90c7ad300f0a4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce5c6f5361452cc8ca90c7ad300f0a4a = L.map(
#                 &quot;map_ce5c6f5361452cc8ca90c7ad300f0a4a&quot;,
#                 {
#                     center: [50.05823257352942, 19.95651992026682],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98566cb84e52459f271eadfe2b7fc662 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ce5c6f5361452cc8ca90c7ad300f0a4a);
#
#
#             var marker_b17a816f9a1b6fb46e2c4c2e374d729f = L.marker(
#                 [50.0758184, 19.9332395],
#                 {}
#             ).addTo(map_ce5c6f5361452cc8ca90c7ad300f0a4a);
#
#
#             var icon_f59f48d4c9cc473c7fd8a3cb432ce60b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b17a816f9a1b6fb46e2c4c2e374d729f.setIcon(icon_f59f48d4c9cc473c7fd8a3cb432ce60b);
#
#
#         var popup_2d8adcdbf8812dc7c807185ccf23cda6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e3d3cee0603859aea85563e9db42927 = $(`&lt;div id=&quot;html_6e3d3cee0603859aea85563e9db42927&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 Wojskowy Szpital Kliniczny z Polikliniką&lt;/div&gt;`)[0];
#                 popup_2d8adcdbf8812dc7c807185ccf23cda6.setContent(html_6e3d3cee0603859aea85563e9db42927);
#
#
#
#         marker_b17a816f9a1b6fb46e2c4c2e374d729f.bindPopup(popup_2d8adcdbf8812dc7c807185ccf23cda6)
#         ;
#
#
#
#
#             var marker_07ce0b08bab0acd64806bf0ef54f840f = L.marker(
#                 [50.089989, 19.9369270722868],
#                 {}
#             ).addTo(map_ce5c6f5361452cc8ca90c7ad300f0a4a);
#
#
#             var icon_a8860c867bed50979ea7045dbfa3879a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_07ce0b08bab0acd64806bf0ef54f840f.setIcon(icon_a8860c867bed50979ea7045dbfa3879a);
#
#
#         var popup_14da6ff59f6e973ec8f98eb185c2a269 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acd6c900b79aa90ce9d808c685af3854 = $(`&lt;div id=&quot;html_acd6c900b79aa90ce9d808c685af3854&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Krakowski Szpital Specjalistyczny im. Jana Pawła II&lt;/div&gt;`)[0];
#                 popup_14da6ff59f6e973ec8f98eb185c2a269.setContent(html_acd6c900b79aa90ce9d808c685af3854);
#
#
#
#         marker_07ce0b08bab0acd64806bf0ef54f840f.bindPopup(popup_14da6ff59f6e973ec8f98eb185c2a269)
#         ;
#
#
#
#
#             var marker_cc7df45b1fb874b579898c3931c3f900 = L.marker(
#                 [50.0636654, 19.8659663],
#                 {}
#             ).addTo(map_ce5c6f5361452cc8ca90c7ad300f0a4a);
#
#
#             var icon_66348c6983c7a2b23575bb53d5dacd8e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cc7df45b1fb874b579898c3931c3f900.setIcon(icon_66348c6983c7a2b23575bb53d5dacd8e);
#
#
#         var popup_5d3c25b8e43f2b18e9b16b4d7689d839 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_70647b566b80acd94d92b8e8e118ff89 = $(`&lt;div id=&quot;html_70647b566b80acd94d92b8e8e118ff89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Małopolski Szpital Ortopedyczno - Rehabilitacyjny im. prof. Bogusława Frańczuka&lt;/div&gt;`)[0];
#                 popup_5d3c25b8e43f2b18e9b16b4d7689d839.setContent(html_70647b566b80acd94d92b8e8e118ff89);
#
#
#
#         marker_cc7df45b1fb874b579898c3931c3f900.bindPopup(popup_5d3c25b8e43f2b18e9b16b4d7689d839)
#         ;
#
#
#
#
#             var marker_b31067574190e9423439ded91251d852 = L.marker(
#                 [50.06163425, 19.927286508712008],
#                 {}
#             ).addTo(map_ce5c6f5361452cc8ca90c7ad300f0a4a);

# %%
get_lat_long(indoor_swimming_pool)
plot_map(indoor_swimming_pool)
# Out:
# 100%|██████████| 42/42 [00:20<00:00,  2.01it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec7f9d060b10f8fdd3d968cafabdc67c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec7f9d060b10f8fdd3d968cafabdc67c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec7f9d060b10f8fdd3d968cafabdc67c = L.map(
#                 &quot;map_ec7f9d060b10f8fdd3d968cafabdc67c&quot;,
#                 {
#                     center: [50.05382756904761, 19.93801954033339],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67183d4c0f878b0f7d06cbfb0d5a0b72 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec7f9d060b10f8fdd3d968cafabdc67c);
#
#
#             var marker_c692a36c06506b9135f49d07dcc8eec0 = L.marker(
#                 [50.06851965, 19.901025398157053],
#                 {}
#             ).addTo(map_ec7f9d060b10f8fdd3d968cafabdc67c);
#
#
#             var icon_0a0a6c5b2f112a3f78dfdae95d765fae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c692a36c06506b9135f49d07dcc8eec0.setIcon(icon_0a0a6c5b2f112a3f78dfdae95d765fae);
#
#
#         var popup_20b3bffcf64896f5b6e166e7be344276 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc40ca8988c28bf75af80e3b862e5830 = $(`&lt;div id=&quot;html_dc40ca8988c28bf75af80e3b862e5830&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Akademia Górniczo Hutnicza&lt;/div&gt;`)[0];
#                 popup_20b3bffcf64896f5b6e166e7be344276.setContent(html_dc40ca8988c28bf75af80e3b862e5830);
#
#
#
#         marker_c692a36c06506b9135f49d07dcc8eec0.bindPopup(popup_20b3bffcf64896f5b6e166e7be344276)
#         ;
#
#
#
#
#             var marker_7ca557da97fa84af651b979e3b07bcbe = L.marker(
#                 [50.07287325, 20.0007516548379],
#                 {}
#             ).addTo(map_ec7f9d060b10f8fdd3d968cafabdc67c);
#
#
#             var icon_841b1ac8f20b1c2896dd7a617d5196e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ca557da97fa84af651b979e3b07bcbe.setIcon(icon_841b1ac8f20b1c2896dd7a617d5196e8);
#
#
#         var popup_7d88df9368b1ad8f5a94c0187e9c97a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56e1da7954e585e65203371c92a35d6e = $(`&lt;div id=&quot;html_56e1da7954e585e65203371c92a35d6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Akademia Wychowania Fizycznego im. Bronisława Czecha Kraków&lt;/div&gt;`)[0];
#                 popup_7d88df9368b1ad8f5a94c0187e9c97a1.setContent(html_56e1da7954e585e65203371c92a35d6e);
#
#
#
#         marker_7ca557da97fa84af651b979e3b07bcbe.bindPopup(popup_7d88df9368b1ad8f5a94c0187e9c97a1)
#         ;
#
#
#
#
#             var marker_9fb439372c9e26d9d9f00c7bedfff086 = L.marker(
#                 [50.0492468, 19.9592908],
#                 {}
#             ).addTo(map_ec7f9d060b10f8fdd3d968cafabdc67c);
#
#
#             var icon_a612dc98c110c8d979e2df892033ae66 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9fb439372c9e26d9d9f00c7bedfff086.setIcon(icon_a612dc98c110c8d979e2df892033ae66);
#
#
#         var popup_b0d2b760c344025ef846ebe500393f19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b827be41828de1b095a52ba7c1da8ec = $(`&lt;div id=&quot;html_7b827be41828de1b095a52ba7c1da8ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Apartamenty Gardiv&lt;/div&gt;`)[0];
#                 popup_b0d2b760c344025ef846ebe500393f19.setContent(html_7b827be41828de1b095a52ba7c1da8ec);
#
#
#
#         marker_9fb439372c9e26d9d9f00c7bedfff086.bindPopup(popup_b0d2b760c344025ef846ebe500393f19)
#         ;
#
#
#
#
#             var marker_7f57d26d8582b991349384028c935b97 = L.marker(
#                 [50.0738521, 19.9352393],
#                 {}
#             ).addTo(map_ec7f9d060b10f8fdd3d968cafabdc67c);
#
#
#             var icon_130d55a1eff0f13b99fbe2f4058579f9 = L.AwesomeMark

# %%
get_lat_long(municipal_police_department)
plot_map(municipal_police_department)
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  2.04it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6598fde61955b25015c4b0e5fae3dbf7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6598fde61955b25015c4b0e5fae3dbf7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6598fde61955b25015c4b0e5fae3dbf7 = L.map(
#                 &quot;map_6598fde61955b25015c4b0e5fae3dbf7&quot;,
#                 {
#                     center: [50.04587341250001, 19.965748031068824],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4b6dcb9dd7ef385a068f2e2c26c5d99 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6598fde61955b25015c4b0e5fae3dbf7);
#
#
#             var marker_b48e043e4f49cdd9388b43c1172f1771 = L.marker(
#                 [50.0242033, 19.9600176],
#                 {}
#             ).addTo(map_6598fde61955b25015c4b0e5fae3dbf7);
#
#
#             var icon_f638914a101e47cb5cff9f3104cc4893 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b48e043e4f49cdd9388b43c1172f1771.setIcon(icon_f638914a101e47cb5cff9f3104cc4893);
#
#
#         var popup_2e9157d32bfafc7769cf97e135e63b29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4b45076380aa4b1db1d6fd7acc20c93 = $(`&lt;div id=&quot;html_f4b45076380aa4b1db1d6fd7acc20c93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Oddział Śródmieście, dzielnice I, II, III&lt;/div&gt;`)[0];
#                 popup_2e9157d32bfafc7769cf97e135e63b29.setContent(html_f4b45076380aa4b1db1d6fd7acc20c93);
#
#
#
#         marker_b48e043e4f49cdd9388b43c1172f1771.bindPopup(popup_2e9157d32bfafc7769cf97e135e63b29)
#         ;
#
#
#
#
#             var marker_13448aa4d37abdf0aa925fadfbc0b64c = L.marker(
#                 [50.0827146, 19.9160102],
#                 {}
#             ).addTo(map_6598fde61955b25015c4b0e5fae3dbf7);
#
#
#             var icon_ef4895ddd7ac4f2bd7a5187942f1790a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13448aa4d37abdf0aa925fadfbc0b64c.setIcon(icon_ef4895ddd7ac4f2bd7a5187942f1790a);
#
#
#         var popup_e8314283af9605c98df4002246b98106 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3e64c84ddb0c40642cea58289bb0204 = $(`&lt;div id=&quot;html_d3e64c84ddb0c40642cea58289bb0204&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Oddział Krowodrza, dzielnice IV, V, VI, VII&lt;/div&gt;`)[0];
#                 popup_e8314283af9605c98df4002246b98106.setContent(html_d3e64c84ddb0c40642cea58289bb0204);
#
#
#
#         marker_13448aa4d37abdf0aa925fadfbc0b64c.bindPopup(popup_e8314283af9605c98df4002246b98106)
#         ;
#
#
#
#
#             var marker_55a69231e945fe886f9aa0cf1ef15afa = L.marker(
#                 [50.07387235, 20.03563042427529],
#                 {}
#             ).addTo(map_6598fde61955b25015c4b0e5fae3dbf7);
#
#
#             var icon_b614aea1a522f79cbc548bd600a57790 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_55a69231e945fe886f9aa0cf1ef15afa.setIcon(icon_b614aea1a522f79cbc548bd600a57790);
#
#
#         var popup_2c36f7e86e42d84dd08998c6a2a447b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80c6cba0be56b1a114f8143baab645a6 = $(`&lt;div id=&quot;html_80c6cba0be56b1a114f8143baab645a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Oddział Nowa Huta, dzielnice XIV, XV, XVI, XVII, XVIII&lt;/div&gt;`)[0];
#                 popup_2c36f7e86e42d84dd08998c6a2a447b8.setContent(html_80c6cba0be56b1a114f8143baab645a6);
#
#
#
#         marker_55a69231e945fe886f9aa0cf1ef15afa.bindPopup(popup_2c36f7e86e42d84dd08998c6a2a447b8)
#         ;
#
#
#
#
#             var marker_e3ce8c5f1ffdc8442a7360b05b1f2343 = L.marker(
#                 [50.0027034, 19.9513339],
#                 {}
#             ).addTo(map_6598fde61955b25015c4b0e5fae3dbf7);
#
#
#             var icon_941a50965226bf40543e

# %%
get_lat_long(museum)
plot_map(museum)
# Out:
# 100%|██████████| 53/53 [00:26<00:00,  2.01it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9d19f9d5a67c6b3aa44784e37049486 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9d19f9d5a67c6b3aa44784e37049486&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9d19f9d5a67c6b3aa44784e37049486 = L.map(
#                 &quot;map_c9d19f9d5a67c6b3aa44784e37049486&quot;,
#                 {
#                     center: [50.05854077264151, 19.938897643415476],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ec92de6fc221980a2d283e92e27f6c5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c9d19f9d5a67c6b3aa44784e37049486);
#
#
#             var marker_1e3bfe564b2e1cae24b8a3059cdde42f = L.marker(
#                 [50.061692199999996, 19.937348815057142],
#                 {}
#             ).addTo(map_c9d19f9d5a67c6b3aa44784e37049486);
#
#
#             var icon_958f5508f4800140d078f7ae30cdd504 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1e3bfe564b2e1cae24b8a3059cdde42f.setIcon(icon_958f5508f4800140d078f7ae30cdd504);
#
#
#         var popup_093318df352ad394d2f7b5ea75fe11cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_449a51e30b5c44b2e01fd86c19b24bfd = $(`&lt;div id=&quot;html_449a51e30b5c44b2e01fd86c19b24bfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galeria Sztuki Polskiej XIX wieku w Sukiennicach&lt;/div&gt;`)[0];
#                 popup_093318df352ad394d2f7b5ea75fe11cd.setContent(html_449a51e30b5c44b2e01fd86c19b24bfd);
#
#
#
#         marker_1e3bfe564b2e1cae24b8a3059cdde42f.bindPopup(popup_093318df352ad394d2f7b5ea75fe11cd)
#         ;
#
#
#
#
#             var marker_5df49b696f8dc3b5b6a4f8ca22137c12 = L.marker(
#                 [50.0614466, 19.929143063723572],
#                 {}
#             ).addTo(map_c9d19f9d5a67c6b3aa44784e37049486);
#
#
#             var icon_57fdffb319780c4d95650593c4ec6e17 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5df49b696f8dc3b5b6a4f8ca22137c12.setIcon(icon_57fdffb319780c4d95650593c4ec6e17);
#
#
#         var popup_f42354496a50a215dc410af907f19964 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ae28586feeff7c3c6814fdf89d1ace1 = $(`&lt;div id=&quot;html_4ae28586feeff7c3c6814fdf89d1ace1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ośrodek Kultury Europejskiej EUROPEUM&lt;/div&gt;`)[0];
#                 popup_f42354496a50a215dc410af907f19964.setContent(html_4ae28586feeff7c3c6814fdf89d1ace1);
#
#
#
#         marker_5df49b696f8dc3b5b6a4f8ca22137c12.bindPopup(popup_f42354496a50a215dc410af907f19964)
#         ;
#
#
#
#
#             var marker_460d61d1c3b2631fc5b5da109ae459a5 = L.marker(
#                 [50.0818425, 20.055299561811285],
#                 {}
#             ).addTo(map_c9d19f9d5a67c6b3aa44784e37049486);
#
#
#             var icon_c7fc9b242de081870897772ddc9ccbc0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_460d61d1c3b2631fc5b5da109ae459a5.setIcon(icon_c7fc9b242de081870897772ddc9ccbc0);
#
#
#         var popup_84bc88de6d4e093208bbb4b29b52b1e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5619a6af45128a0f571e3936008b8ba = $(`&lt;div id=&quot;html_b5619a6af45128a0f571e3936008b8ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dworek Jana Matejki w Krzesławicach&lt;/div&gt;`)[0];
#                 popup_84bc88de6d4e093208bbb4b29b52b1e6.setContent(html_b5619a6af45128a0f571e3936008b8ba);
#
#
#
#         marker_460d61d1c3b2631fc5b5da109ae459a5.bindPopup(popup_84bc88de6d4e093208bbb4b29b52b1e6)
#         ;
#
#
#
#
#             var marker_01950a46d9edbc1079cb74ad7f1008cd = L.marker(
#                 [50.063835049999994, 19.941001097367007],
#                 {}
#             ).addTo(map_c9d19f9d5a67c6b3aa44784e37049486);
#
#
#             var ico

# %%
get_lat_long(natural_swimming_pool)
plot_map(natural_swimming_pool)
# Out:
# 100%|██████████| 6/6 [00:03<00:00,  1.53it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8983c5318766fe0b5722e4fb63bacf07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8983c5318766fe0b5722e4fb63bacf07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8983c5318766fe0b5722e4fb63bacf07 = L.map(
#                 &quot;map_8983c5318766fe0b5722e4fb63bacf07&quot;,
#                 {
#                     center: [50.04791746666667, 19.965595987742102],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c734bb595aae5f138d7c609569c50ac2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8983c5318766fe0b5722e4fb63bacf07);
#
#
#             var marker_829d547305910f6e7242398e550308ec = L.marker(
#                 [50.0329, 19.993695326452595],
#                 {}
#             ).addTo(map_8983c5318766fe0b5722e4fb63bacf07);
#
#
#             var icon_eb6657bdcdc38064cb58ac1f1602dd12 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_829d547305910f6e7242398e550308ec.setIcon(icon_eb6657bdcdc38064cb58ac1f1602dd12);
#
#
#         var popup_70a5ca0f265c02e721830f30a4d6702d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad19a0bb32e94e5cc0c78084de6da3b4 = $(`&lt;div id=&quot;html_ad19a0bb32e94e5cc0c78084de6da3b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kąpielisko Plaża Bagry - Stowarzyszenie Omega&lt;/div&gt;`)[0];
#                 popup_70a5ca0f265c02e721830f30a4d6702d.setContent(html_ad19a0bb32e94e5cc0c78084de6da3b4);
#
#
#
#         marker_829d547305910f6e7242398e550308ec.bindPopup(popup_70a5ca0f265c02e721830f30a4d6702d)
#         ;
#
#
#
#
#             var marker_3f43b24a716f5df5fcdb4f51bcaad810 = L.marker(
#                 [50.0583135, 20.1565862],
#                 {}
#             ).addTo(map_8983c5318766fe0b5722e4fb63bacf07);
#
#
#             var icon_509f22d1d0704b0e2039bb0a2b87d17e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3f43b24a716f5df5fcdb4f51bcaad810.setIcon(icon_509f22d1d0704b0e2039bb0a2b87d17e);
#
#
#         var popup_0ce42c4f12326e64c82a9cef1133b07f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d303353f9bc5c4a6f67434402e3d5b5a = $(`&lt;div id=&quot;html_d303353f9bc5c4a6f67434402e3d5b5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kąpielisko Przylasek Rusiecki Zbiornik nr 1 - Centrum Sportów Wodnych WAKE CAMP KRAKÓW&lt;/div&gt;`)[0];
#                 popup_0ce42c4f12326e64c82a9cef1133b07f.setContent(html_d303353f9bc5c4a6f67434402e3d5b5a);
#
#
#
#         marker_3f43b24a716f5df5fcdb4f51bcaad810.bindPopup(popup_0ce42c4f12326e64c82a9cef1133b07f)
#         ;
#
#
#
#
#             var marker_4c11ee0098887d7f2475ebdfe286bf64 = L.marker(
#                 [50.0371512, 20.0662982],
#                 {}
#             ).addTo(map_8983c5318766fe0b5722e4fb63bacf07);
#
#
#             var icon_23b2e8f9b4fef13338377f36c6c52aca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4c11ee0098887d7f2475ebdfe286bf64.setIcon(icon_23b2e8f9b4fef13338377f36c6c52aca);
#
#
#         var popup_2898db0aee6c452f6832ce46e95220d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d94c7358500b79cb97297c18cbac4f95 = $(`&lt;div id=&quot;html_d94c7358500b79cb97297c18cbac4f95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kąpielisko Przystań Brzegi&lt;/div&gt;`)[0];
#                 popup_2898db0aee6c452f6832ce46e95220d1.setContent(html_d94c7358500b79cb97297c18cbac4f95);
#
#
#
#         marker_4c11ee0098887d7f2475ebdfe286bf64.bindPopup(popup_2898db0aee6c452f6832ce46e95220d1)
#         ;
#
#
#
#
#             var marker_3375822b2a94a2895051c632f7e4b3b4 = L.marker(
#                 [50.0384673, 19.7661585],
#                 {}
#             ).addTo(map_8983c5318766fe0b5722e4fb63bacf07);
#
#
#             var icon_6b77

# %%
get_lat_long(orlik_soccer_field)
plot_map(orlik_soccer_field)
# Out:
# 100%|██████████| 20/20 [00:09<00:00,  2.01it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a128e35064e4301b3bd3645ca4c81d75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a128e35064e4301b3bd3645ca4c81d75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a128e35064e4301b3bd3645ca4c81d75 = L.map(
#                 &quot;map_a128e35064e4301b3bd3645ca4c81d75&quot;,
#                 {
#                     center: [50.049684942499994, 19.97134699832884],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_889a9180edd24f28c4068c51ac579464 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a128e35064e4301b3bd3645ca4c81d75);
#
#
#             var marker_cbc92b84eb9e3a96868687a7bf6301bd = L.marker(
#                 [50.0227511, 19.8686541782718],
#                 {}
#             ).addTo(map_a128e35064e4301b3bd3645ca4c81d75);
#
#
#             var icon_b1f3ca78a283ae2fe47150eb704ffb04 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cbc92b84eb9e3a96868687a7bf6301bd.setIcon(icon_b1f3ca78a283ae2fe47150eb704ffb04);
#
#
#         var popup_e8037e52ddf7053cbadf4d03c4763f65 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bbc6c0ae7cf19bffc4ed6806fc232f8 = $(`&lt;div id=&quot;html_1bbc6c0ae7cf19bffc4ed6806fc232f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;J&amp;J Center Skotniki&lt;/div&gt;`)[0];
#                 popup_e8037e52ddf7053cbadf4d03c4763f65.setContent(html_1bbc6c0ae7cf19bffc4ed6806fc232f8);
#
#
#
#         marker_cbc92b84eb9e3a96868687a7bf6301bd.bindPopup(popup_e8037e52ddf7053cbadf4d03c4763f65)
#         ;
#
#
#
#
#             var marker_146cc1e08bd73cfc9d7b49f72436d6ed = L.marker(
#                 [50.0186881, 20.00795403385912],
#                 {}
#             ).addTo(map_a128e35064e4301b3bd3645ca4c81d75);
#
#
#             var icon_43f61e24cbde131a0b5a5ccd19f8ba05 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_146cc1e08bd73cfc9d7b49f72436d6ed.setIcon(icon_43f61e24cbde131a0b5a5ccd19f8ba05);
#
#
#         var popup_c31495f36e49a761fec45b6fb49a1f09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8a04486f85c152249fc178efe9f78a9 = $(`&lt;div id=&quot;html_d8a04486f85c152249fc178efe9f78a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KS Kolejarz Prokocim&lt;/div&gt;`)[0];
#                 popup_c31495f36e49a761fec45b6fb49a1f09.setContent(html_d8a04486f85c152249fc178efe9f78a9);
#
#
#
#         marker_146cc1e08bd73cfc9d7b49f72436d6ed.bindPopup(popup_c31495f36e49a761fec45b6fb49a1f09)
#         ;
#
#
#
#
#             var marker_5356786b103c0d974406dc480cc5320e = L.marker(
#                 [50.0223004, 19.9859548],
#                 {}
#             ).addTo(map_a128e35064e4301b3bd3645ca4c81d75);
#
#
#             var icon_59742d6bf688f1aab20433092b432ffc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5356786b103c0d974406dc480cc5320e.setIcon(icon_59742d6bf688f1aab20433092b432ffc);
#
#
#         var popup_5fdf37b3ad8a7f76da231362c4b47034 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7440621c4e5851ce8c352eb5c73e236c = $(`&lt;div id=&quot;html_7440621c4e5851ce8c352eb5c73e236c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Orlik 2012 – kompleks boisk sportowych&lt;/div&gt;`)[0];
#                 popup_5fdf37b3ad8a7f76da231362c4b47034.setContent(html_7440621c4e5851ce8c352eb5c73e236c);
#
#
#
#         marker_5356786b103c0d974406dc480cc5320e.bindPopup(popup_5fdf37b3ad8a7f76da231362c4b47034)
#         ;
#
#
#
#
#             var marker_cb6f2b2423e2d8ae2bb397a297841772 = L.marker(
#                 [50.0104179, 19.950672356669266],
#                 {}
#             ).addTo(map_a128e35064e4301b3bd3645ca4c81d75);
#
#
#             var icon_2bdd65706ef6c3b0695a3b9770ef1138 = L.AwesomeMarkers.icon(

# %%
get_lat_long(pharmacy)
plot_map(pharmacy)
# Out:
# 100%|██████████| 281/281 [02:22<00:00,  1.97it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de72496876a740859dc555ede6177e61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de72496876a740859dc555ede6177e61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de72496876a740859dc555ede6177e61 = L.map(
#                 &quot;map_de72496876a740859dc555ede6177e61&quot;,
#                 {
#                     center: [50.05991586476867, 19.957824599247413],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_400d006834e70ad7880573bfa31d9e4a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de72496876a740859dc555ede6177e61);
#
#
#             var marker_bafd15d59140376409bedc20d2ffffff = L.marker(
#                 [50.0877216, 19.9275998],
#                 {}
#             ).addTo(map_de72496876a740859dc555ede6177e61);
#
#
#             var icon_bc5f7c70c5297597d593bbef1975f74f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bafd15d59140376409bedc20d2ffffff.setIcon(icon_bc5f7c70c5297597d593bbef1975f74f);
#
#
#         var popup_9b78db3ac73ea38deb5380328c2800db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4d2cba18b3a372c5a63c7f4c851f39a = $(`&lt;div id=&quot;html_d4d2cba18b3a372c5a63c7f4c851f39a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&quot;ADART&quot; APTEKA&lt;/div&gt;`)[0];
#                 popup_9b78db3ac73ea38deb5380328c2800db.setContent(html_d4d2cba18b3a372c5a63c7f4c851f39a);
#
#
#
#         marker_bafd15d59140376409bedc20d2ffffff.bindPopup(popup_9b78db3ac73ea38deb5380328c2800db)
#         ;
#
#
#
#
#             var marker_f6794a9f812ca888d93561e37190b283 = L.marker(
#                 [50.0822578, 20.0037509],
#                 {}
#             ).addTo(map_de72496876a740859dc555ede6177e61);
#
#
#             var icon_14cfeda95ab8ff2ea9efb5d51eef0eaf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f6794a9f812ca888d93561e37190b283.setIcon(icon_14cfeda95ab8ff2ea9efb5d51eef0eaf);
#
#
#         var popup_9cac2eb9eac6f6674a0680232e2089af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b22ddb24143eff6feb2eec26e8b8ecec = $(`&lt;div id=&quot;html_b22ddb24143eff6feb2eec26e8b8ecec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&quot; ALOKA&quot;&lt;/div&gt;`)[0];
#                 popup_9cac2eb9eac6f6674a0680232e2089af.setContent(html_b22ddb24143eff6feb2eec26e8b8ecec);
#
#
#
#         marker_f6794a9f812ca888d93561e37190b283.bindPopup(popup_9cac2eb9eac6f6674a0680232e2089af)
#         ;
#
#
#
#
#             var marker_52e7a68bd213f4ad913f9ee0a9a92431 = L.marker(
#                 [50.0737361, 19.9590865],
#                 {}
#             ).addTo(map_de72496876a740859dc555ede6177e61);
#
#
#             var icon_93a2ed7652c2559249af9edb70bfc6aa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_52e7a68bd213f4ad913f9ee0a9a92431.setIcon(icon_93a2ed7652c2559249af9edb70bfc6aa);
#
#
#         var popup_c7f461a936edd43d6bf69b27d4b871d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10a6c09f4369359e14fb4448e1b71485 = $(`&lt;div id=&quot;html_10a6c09f4369359e14fb4448e1b71485&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Apteka&lt;/div&gt;`)[0];
#                 popup_c7f461a936edd43d6bf69b27d4b871d0.setContent(html_10a6c09f4369359e14fb4448e1b71485);
#
#
#
#         marker_52e7a68bd213f4ad913f9ee0a9a92431.bindPopup(popup_c7f461a936edd43d6bf69b27d4b871d0)
#         ;
#
#
#
#
#             var marker_2bb591e65f8707527695ee87179eedb6 = L.marker(
#                 [50.0619005, 19.9274235],
#                 {}
#             ).addTo(map_de72496876a740859dc555ede6177e61);
#
#
#             var icon_5a85752a253d4de93fd0289df7ffdd91 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0

# %%
get_lat_long(police_station)
plot_map(police_station)
# Out:
# 100%|██████████| 11/11 [00:05<00:00,  2.08it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a229ecab4a6314af90aafc47ce26c991 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a229ecab4a6314af90aafc47ce26c991&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a229ecab4a6314af90aafc47ce26c991 = L.map(
#                 &quot;map_a229ecab4a6314af90aafc47ce26c991&quot;,
#                 {
#                     center: [50.06550508181818, 19.9664554432817],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d24a30baa2ac7257793367ef01d797e8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a229ecab4a6314af90aafc47ce26c991);
#
#
#             var marker_04877a02450eb25080fd36d54d076e64 = L.marker(
#                 [50.0522801, 19.9479472],
#                 {}
#             ).addTo(map_a229ecab4a6314af90aafc47ce26c991);
#
#
#             var icon_b3a8767e038f79de4d5e37a4dbd1bd51 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_04877a02450eb25080fd36d54d076e64.setIcon(icon_b3a8767e038f79de4d5e37a4dbd1bd51);
#
#
#         var popup_03823a43dd107a830abf8e8a60a19d0d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2117d15a2ae791eb7fc23fab647c78d8 = $(`&lt;div id=&quot;html_2117d15a2ae791eb7fc23fab647c78d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KOMISARIAT POLICJI I W KRAKOWIE SIEDZIBA GŁÓWNA&lt;/div&gt;`)[0];
#                 popup_03823a43dd107a830abf8e8a60a19d0d.setContent(html_2117d15a2ae791eb7fc23fab647c78d8);
#
#
#
#         marker_04877a02450eb25080fd36d54d076e64.bindPopup(popup_03823a43dd107a830abf8e8a60a19d0d)
#         ;
#
#
#
#
#             var marker_c3d1d99fae7e78eda834e0b11013d87f = L.marker(
#                 [50.069549, 19.9383464],
#                 {}
#             ).addTo(map_a229ecab4a6314af90aafc47ce26c991);
#
#
#             var icon_8ddd8db47d1bc00a9ef628bd13f53792 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c3d1d99fae7e78eda834e0b11013d87f.setIcon(icon_8ddd8db47d1bc00a9ef628bd13f53792);
#
#
#         var popup_0e4ec20ceca0344c0a2aaba93e33bd23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9b84666e0835a93e6bf6c66dde8e25d = $(`&lt;div id=&quot;html_f9b84666e0835a93e6bf6c66dde8e25d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KOMISARIAT POLICJI I W KRAKOWIE SIEDZIBA POMOCNICZA&lt;/div&gt;`)[0];
#                 popup_0e4ec20ceca0344c0a2aaba93e33bd23.setContent(html_f9b84666e0835a93e6bf6c66dde8e25d);
#
#
#
#         marker_c3d1d99fae7e78eda834e0b11013d87f.bindPopup(popup_0e4ec20ceca0344c0a2aaba93e33bd23)
#         ;
#
#
#
#
#             var marker_5aa12fda5f5aa3f56cd8f5245326e2b7 = L.marker(
#                 [50.06191735, 19.935357674476414],
#                 {}
#             ).addTo(map_a229ecab4a6314af90aafc47ce26c991);
#
#
#             var icon_314875f11cf74702c4f6d9ca37299999 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5aa12fda5f5aa3f56cd8f5245326e2b7.setIcon(icon_314875f11cf74702c4f6d9ca37299999);
#
#
#         var popup_5acc2b7d9ea6beabbe04723f2c5ee575 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_522c95d7226dcba8866801a8b33efe20 = $(`&lt;div id=&quot;html_522c95d7226dcba8866801a8b33efe20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KOMISARIAT POLICJI I W KRAKOWIE SIEDZIBA POMOCNICZA&lt;/div&gt;`)[0];
#                 popup_5acc2b7d9ea6beabbe04723f2c5ee575.setContent(html_522c95d7226dcba8866801a8b33efe20);
#
#
#
#         marker_5aa12fda5f5aa3f56cd8f5245326e2b7.bindPopup(popup_5acc2b7d9ea6beabbe04723f2c5ee575)
#         ;
#
#
#
#
#             var marker_251a800bad9fd49b883fdcabdf00dc68 = L.marker(
#                 [50.0648832, 19.9504855],
#                 {}
#             ).addTo(map_a229ecab4a6314af90aafc47ce26c991);
#
#
#             var icon_77c2ac33132

# %%
get_lat_long(primary_care_units)
plot_map(primary_care_units)
# Out:
# 100%|██████████| 191/191 [01:35<00:00,  2.00it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_effdb433b8a548cced73061f3e94f2d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_effdb433b8a548cced73061f3e94f2d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_effdb433b8a548cced73061f3e94f2d6 = L.map(
#                 &quot;map_effdb433b8a548cced73061f3e94f2d6&quot;,
#                 {
#                     center: [50.06059033429319, 19.963244821496684],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e61a42531ea064c284c61af7cbd3700 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_effdb433b8a548cced73061f3e94f2d6);
#
#
#             var marker_a09b9b772ac1edd9a595b85960c48030 = L.marker(
#                 [50.0758184, 19.9332395],
#                 {}
#             ).addTo(map_effdb433b8a548cced73061f3e94f2d6);
#
#
#             var icon_376eb61295f22915300c71ddf9dc2ab5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a09b9b772ac1edd9a595b85960c48030.setIcon(icon_376eb61295f22915300c71ddf9dc2ab5);
#
#
#         var popup_b233e5297c6905a2c234a9439b903f4d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a20851307514d685b9324bf66014f0eb = $(`&lt;div id=&quot;html_a20851307514d685b9324bf66014f0eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 Wojskowy Szpital Kliniczny z Polikliniką - Samodzielny Publiczny Zakład Opieki Zdrowotnej w Krakowie&lt;/div&gt;`)[0];
#                 popup_b233e5297c6905a2c234a9439b903f4d.setContent(html_a20851307514d685b9324bf66014f0eb);
#
#
#
#         marker_a09b9b772ac1edd9a595b85960c48030.bindPopup(popup_b233e5297c6905a2c234a9439b903f4d)
#         ;
#
#
#
#
#             var marker_a54b92fb329b5c054f9efc930905042c = L.marker(
#                 [50.0690422, 19.9379184],
#                 {}
#             ).addTo(map_effdb433b8a548cced73061f3e94f2d6);
#
#
#             var icon_46c8bd60f77acc50034ea486ed82b0dd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a54b92fb329b5c054f9efc930905042c.setIcon(icon_46c8bd60f77acc50034ea486ed82b0dd);
#
#
#         var popup_7ef537e8222d7584be00c09f28678e4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a25259c65e9036567caba2f1932679ab = $(`&lt;div id=&quot;html_a25259c65e9036567caba2f1932679ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ad Aegrotum Niepubliczny Zakład Opieki Zdrowotnej Spółka z ograniczoną odpowiedzialnością&lt;/div&gt;`)[0];
#                 popup_7ef537e8222d7584be00c09f28678e4b.setContent(html_a25259c65e9036567caba2f1932679ab);
#
#
#
#         marker_a54b92fb329b5c054f9efc930905042c.bindPopup(popup_7ef537e8222d7584be00c09f28678e4b)
#         ;
#
#
#
#
#             var marker_88fa0ea9852369fc168b1f0b785f2033 = L.marker(
#                 [50.057420300000004, 19.98000602868538],
#                 {}
#             ).addTo(map_effdb433b8a548cced73061f3e94f2d6);
#
#
#             var icon_a7cc5362d719d9ac0a8decb48a2446bb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88fa0ea9852369fc168b1f0b785f2033.setIcon(icon_a7cc5362d719d9ac0a8decb48a2446bb);
#
#
#         var popup_7a6eda1a5e1248d4857b39c0c95e66a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd0f665b67f1279225d488a28fb1a586 = $(`&lt;div id=&quot;html_fd0f665b67f1279225d488a28fb1a586&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aleksandra Wróbel Niepubliczny Zakład Opieki Zdrowotnej &quot;OLMED&quot; - Opieka Pielęgniarska&lt;/div&gt;`)[0];
#                 popup_7a6eda1a5e1248d4857b39c0c95e66a9.setContent(html_fd0f665b67f1279225d488a28fb1a586);
#
#
#
#         marker_88fa0ea9852369fc168b1f0b785f2033.bindPopup(popup_7a6eda1a5e1248d4857b39c0c95e66a9)
#         ;
#
#
#
#
#             var marker_568ae0a4155edca07f03182d69286517 = L.marker(
#                 [50

# %%
get_lat_long(primary_school)
plot_map(primary_school)
# Out:
# 100%|██████████| 203/203 [01:41<00:00,  2.00it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9281a17c83e58d27237ac6f9a312b01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9281a17c83e58d27237ac6f9a312b01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9281a17c83e58d27237ac6f9a312b01 = L.map(
#                 &quot;map_b9281a17c83e58d27237ac6f9a312b01&quot;,
#                 {
#                     center: [50.0567630357143, 19.95955372623452],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50e2e173cc5ed02dae03dc7498327093 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b9281a17c83e58d27237ac6f9a312b01);
#
#
#             var marker_7e9e165d82a547199e0ee11733af0483 = L.marker(
#                 [50.0627745, 19.9434834],
#                 {}
#             ).addTo(map_b9281a17c83e58d27237ac6f9a312b01);
#
#
#             var icon_da37b9f81daf5754484f067e8793d80c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7e9e165d82a547199e0ee11733af0483.setIcon(icon_da37b9f81daf5754484f067e8793d80c);
#
#
#         var popup_2da8ffa7c3d7ac98577eac850cf01057 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e1a646bf36e8a5ae09519390d576df9c = $(`&lt;div id=&quot;html_e1a646bf36e8a5ae09519390d576df9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Szkoła Podstawowa nr 1 im. Komisji Edukacji Narodowej&lt;/div&gt;`)[0];
#                 popup_2da8ffa7c3d7ac98577eac850cf01057.setContent(html_e1a646bf36e8a5ae09519390d576df9c);
#
#
#
#         marker_7e9e165d82a547199e0ee11733af0483.bindPopup(popup_2da8ffa7c3d7ac98577eac850cf01057)
#         ;
#
#
#
#
#             var marker_ab36b20d54e8a0e75f2571f006c0865f = L.marker(
#                 [50.055373599999996, 19.950977728521657],
#                 {}
#             ).addTo(map_b9281a17c83e58d27237ac6f9a312b01);
#
#
#             var icon_6119e30004ad9993028269bf49046da0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ab36b20d54e8a0e75f2571f006c0865f.setIcon(icon_6119e30004ad9993028269bf49046da0);
#
#
#         var popup_75e14dc11e0bb045a971c18178796bb7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4f4b566c13f4706d4f4eeb6c40713a1 = $(`&lt;div id=&quot;html_d4f4b566c13f4706d4f4eeb6c40713a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Szkoła Podstawowa nr 10 im. Marii Skłodowskiej-Curie&lt;/div&gt;`)[0];
#                 popup_75e14dc11e0bb045a971c18178796bb7.setContent(html_d4f4b566c13f4706d4f4eeb6c40713a1);
#
#
#
#         marker_ab36b20d54e8a0e75f2571f006c0865f.bindPopup(popup_75e14dc11e0bb045a971c18178796bb7)
#         ;
#
#
#
#
#             var marker_871a2214cffa794de36ea1362761d587 = L.marker(
#                 [50.08082655, 20.019804695571096],
#                 {}
#             ).addTo(map_b9281a17c83e58d27237ac6f9a312b01);
#
#
#             var icon_83188b2f3c159f723c3c68578f3583af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_871a2214cffa794de36ea1362761d587.setIcon(icon_83188b2f3c159f723c3c68578f3583af);
#
#
#         var popup_74093cb7dea63faeb2b36d84efd9defb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9ceccfb08e80feb88ca15ebcfb93d8c = $(`&lt;div id=&quot;html_b9ceccfb08e80feb88ca15ebcfb93d8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Szkoła Podstawowa nr 100 im. Adama Mickiewicza&lt;/div&gt;`)[0];
#                 popup_74093cb7dea63faeb2b36d84efd9defb.setContent(html_b9ceccfb08e80feb88ca15ebcfb93d8c);
#
#
#
#         marker_871a2214cffa794de36ea1362761d587.bindPopup(popup_74093cb7dea63faeb2b36d84efd9defb)
#         ;
#
#
#
#
#             var marker_82a6095b7dde9133f08777f8cf92064b = L.marker(
#                 [50.088657299999994, 20.023345806734795],
#                 {}
#             ).addTo(map_b9281a17c83e58d27237ac6f9a312b01);

# %%
get_lat_long(roman_catholic_church)
plot_map(roman_catholic_church)
# Out:
# 100%|██████████| 137/137 [01:08<00:00,  2.00it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cdee691de4e4ecff4bd6d533cce8a0ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cdee691de4e4ecff4bd6d533cce8a0ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cdee691de4e4ecff4bd6d533cce8a0ad = L.map(
#                 &quot;map_cdee691de4e4ecff4bd6d533cce8a0ad&quot;,
#                 {
#                     center: [50.05683075620437, 19.951293882405405],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac9bb3f09ce835062482e5c61fc4cb16 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cdee691de4e4ecff4bd6d533cce8a0ad);
#
#
#             var marker_43b67a9ce69902bfb032b820b58f8753 = L.marker(
#                 [50.05126435, 19.93971205391791],
#                 {}
#             ).addTo(map_cdee691de4e4ecff4bd6d533cce8a0ad);
#
#
#             var icon_3ab6187e099f54dc2262514e9ae3601e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_43b67a9ce69902bfb032b820b58f8753.setIcon(icon_3ab6187e099f54dc2262514e9ae3601e);
#
#
#         var popup_17091364dc97618fc9ec9e6d405dc33a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a649ffaff880d8c8a9156aafe9ee4b35 = $(`&lt;div id=&quot;html_a649ffaff880d8c8a9156aafe9ee4b35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kościół św. Agnieszki&lt;/div&gt;`)[0];
#                 popup_17091364dc97618fc9ec9e6d405dc33a.setContent(html_a649ffaff880d8c8a9156aafe9ee4b35);
#
#
#
#         marker_43b67a9ce69902bfb032b820b58f8753.bindPopup(popup_17091364dc97618fc9ec9e6d405dc33a)
#         ;
#
#
#
#
#             var marker_e88d074f97515f00159d9216a4c5c819 = L.marker(
#                 [50.056589849999995, 19.938428785175578],
#                 {}
#             ).addTo(map_cdee691de4e4ecff4bd6d533cce8a0ad);
#
#
#             var icon_b0c4b0c95c06901a0d5341794dc77420 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e88d074f97515f00159d9216a4c5c819.setIcon(icon_b0c4b0c95c06901a0d5341794dc77420);
#
#
#         var popup_bd5e067222d19bdb7dbb40eb68a562ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11770f14ae46333d13957c52ec4e1516 = $(`&lt;div id=&quot;html_11770f14ae46333d13957c52ec4e1516&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kościół św. Andrzeja&lt;/div&gt;`)[0];
#                 popup_bd5e067222d19bdb7dbb40eb68a562ed.setContent(html_11770f14ae46333d13957c52ec4e1516);
#
#
#
#         marker_e88d074f97515f00159d9216a4c5c819.bindPopup(popup_bd5e067222d19bdb7dbb40eb68a562ed)
#         ;
#
#
#
#
#             var marker_c483d0c8f871ec050e3bb4e34d818fcf = L.marker(
#                 [50.07679945, 19.916490378858015],
#                 {}
#             ).addTo(map_cdee691de4e4ecff4bd6d533cce8a0ad);
#
#
#             var icon_bfba1e68490352816e0f79599152ea81 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c483d0c8f871ec050e3bb4e34d818fcf.setIcon(icon_bfba1e68490352816e0f79599152ea81);
#
#
#         var popup_ed2037ba327fdecee61a40df4f3ee9c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_debce2acb6ffa68d6fd6436910962a20 = $(`&lt;div id=&quot;html_debce2acb6ffa68d6fd6436910962a20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kościół bł. Anieli Salawy&lt;/div&gt;`)[0];
#                 popup_ed2037ba327fdecee61a40df4f3ee9c7.setContent(html_debce2acb6ffa68d6fd6436910962a20);
#
#
#
#         marker_c483d0c8f871ec050e3bb4e34d818fcf.bindPopup(popup_ed2037ba327fdecee61a40df4f3ee9c7)
#         ;
#
#
#
#
#             var marker_bdc6e05c9c821f4e7992a97af508a502 = L.marker(
#                 [50.06239575, 19.933562623285756],
#                 {}
#             ).addTo(map_cdee691de4e4ecff4bd6d533cce8a0ad);
#
#
#             var icon_eaa8270447bd4f36d1ea541bdeba8e1f = L.AwesomeMarkers.icon(

# %%
get_lat_long(rope_park)
plot_map(rope_park)
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  2.58it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf6230d81f1c28e466a74a6bac5aa370 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf6230d81f1c28e466a74a6bac5aa370&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf6230d81f1c28e466a74a6bac5aa370 = L.map(
#                 &quot;map_bf6230d81f1c28e466a74a6bac5aa370&quot;,
#                 {
#                     center: [50.0483068, 19.86422215],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d725a75587413de953eb9f759c8d8036 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bf6230d81f1c28e466a74a6bac5aa370);
#
#
#             var marker_1c93d8321dee5a7511e65bfbad89abf0 = L.marker(
#                 [50.0324022, 19.8578975],
#                 {}
#             ).addTo(map_bf6230d81f1c28e466a74a6bac5aa370);
#
#
#             var icon_35db3bde1f3786955d3dcca8d3ba1584 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1c93d8321dee5a7511e65bfbad89abf0.setIcon(icon_35db3bde1f3786955d3dcca8d3ba1584);
#
#
#         var popup_8f496db5741695d3a5609f5e417ef7f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_49a5f9c8e7b692711ffc983f0e2b37fe = $(`&lt;div id=&quot;html_49a5f9c8e7b692711ffc983f0e2b37fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Krakowski park linowy&lt;/div&gt;`)[0];
#                 popup_8f496db5741695d3a5609f5e417ef7f2.setContent(html_49a5f9c8e7b692711ffc983f0e2b37fe);
#
#
#
#         marker_1c93d8321dee5a7511e65bfbad89abf0.bindPopup(popup_8f496db5741695d3a5609f5e417ef7f2)
#         ;
#
#
#
#
#             var marker_2e7e30fe2d8d9491291e6d1c3cce1627 = L.marker(
#                 [50.0642114, 19.8705468],
#                 {}
#             ).addTo(map_bf6230d81f1c28e466a74a6bac5aa370);
#
#
#             var icon_14b11b57ae5ae172421a1a00c4864d3e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2e7e30fe2d8d9491291e6d1c3cce1627.setIcon(icon_14b11b57ae5ae172421a1a00c4864d3e);
#
#
#         var popup_317982f7695482c7b09c36ac4f135465 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_434cc9792f4bf89d943125e3f87ef60d = $(`&lt;div id=&quot;html_434cc9792f4bf89d943125e3f87ef60d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Park Wola – Rodzinny Park Rozrywki&lt;/div&gt;`)[0];
#                 popup_317982f7695482c7b09c36ac4f135465.setContent(html_434cc9792f4bf89d943125e3f87ef60d);
#
#
#
#         marker_2e7e30fe2d8d9491291e6d1c3cce1627.bindPopup(popup_317982f7695482c7b09c36ac4f135465)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
get_lat_long(rossmann)
plot_map(rossmann)
# Out:
# 100%|██████████| 49/49 [00:24<00:00,  2.00it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5306b07f6f30cb250e68892599c5e22a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5306b07f6f30cb250e68892599c5e22a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5306b07f6f30cb250e68892599c5e22a = L.map(
#                 &quot;map_5306b07f6f30cb250e68892599c5e22a&quot;,
#                 {
#                     center: [50.05756128877551, 19.954804600914414],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34588e9130d7fe3a75808f9fa5fbb186 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5306b07f6f30cb250e68892599c5e22a);
#
#
#             var marker_d6278460d843525c4ab8df9c31fc1fc5 = L.marker(
#                 [50.0675936, 19.946146666336773],
#                 {}
#             ).addTo(map_5306b07f6f30cb250e68892599c5e22a);
#
#
#             var icon_14020aa6652ed11cd8a18002388806ff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d6278460d843525c4ab8df9c31fc1fc5.setIcon(icon_14020aa6652ed11cd8a18002388806ff);
#
#
#         var popup_0ab080d71ae86bd75ff19925dc31401f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d757ece845a148826f76d1a34be82a5 = $(`&lt;div id=&quot;html_2d757ece845a148826f76d1a34be82a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rossmann&lt;/div&gt;`)[0];
#                 popup_0ab080d71ae86bd75ff19925dc31401f.setContent(html_2d757ece845a148826f76d1a34be82a5);
#
#
#
#         marker_d6278460d843525c4ab8df9c31fc1fc5.bindPopup(popup_0ab080d71ae86bd75ff19925dc31401f)
#         ;
#
#
#
#
#             var marker_a9ba387b80557e3770b6ed187caad112 = L.marker(
#                 [50.0675936, 19.946146666336773],
#                 {}
#             ).addTo(map_5306b07f6f30cb250e68892599c5e22a);
#
#
#             var icon_c317d50c08a78a20562c4092638bb62f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a9ba387b80557e3770b6ed187caad112.setIcon(icon_c317d50c08a78a20562c4092638bb62f);
#
#
#         var popup_cd643c54af638e734ebcf34abab55ac5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_247602009a847534e3c00fb7eeda258f = $(`&lt;div id=&quot;html_247602009a847534e3c00fb7eeda258f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rossmann&lt;/div&gt;`)[0];
#                 popup_cd643c54af638e734ebcf34abab55ac5.setContent(html_247602009a847534e3c00fb7eeda258f);
#
#
#
#         marker_a9ba387b80557e3770b6ed187caad112.bindPopup(popup_cd643c54af638e734ebcf34abab55ac5)
#         ;
#
#
#
#
#             var marker_dcabf1593ad7cdd351ef763791adbdae = L.marker(
#                 [50.0615775, 19.94106],
#                 {}
#             ).addTo(map_5306b07f6f30cb250e68892599c5e22a);
#
#
#             var icon_27b2ad3890dfb55112fb3f580fa748c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dcabf1593ad7cdd351ef763791adbdae.setIcon(icon_27b2ad3890dfb55112fb3f580fa748c6);
#
#
#         var popup_789307beed32b5d152b6f25a2c06e1b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_660f6a549ca3516b0ab7818f69f895d0 = $(`&lt;div id=&quot;html_660f6a549ca3516b0ab7818f69f895d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rossmann&lt;/div&gt;`)[0];
#                 popup_789307beed32b5d152b6f25a2c06e1b6.setContent(html_660f6a549ca3516b0ab7818f69f895d0);
#
#
#
#         marker_dcabf1593ad7cdd351ef763791adbdae.bindPopup(popup_789307beed32b5d152b6f25a2c06e1b6)
#         ;
#
#
#
#
#             var marker_ad04be3b7db5a05fe3fe2ddf58085204 = L.marker(
#                 [50.0522476, 19.9416538],
#                 {}
#             ).addTo(map_5306b07f6f30cb250e68892599c5e22a);
#
#
#             var icon_aca942fecca9dbd496a6e817dbb9ddef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &q

# %%
get_lat_long(shopping_center)
plot_map(shopping_center)
# Out:
# 100%|██████████| 13/13 [00:06<00:00,  1.99it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54c1c0ca058e3d3df3563783fc82c85d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54c1c0ca058e3d3df3563783fc82c85d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54c1c0ca058e3d3df3563783fc82c85d = L.map(
#                 &quot;map_54c1c0ca058e3d3df3563783fc82c85d&quot;,
#                 {
#                     center: [50.05579595769231, 19.948316790266134],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b4ef38626373a803573ba3f3d7085c9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_54c1c0ca058e3d3df3563783fc82c85d);
#
#
#             var marker_7dd2a5ae91feb4ffbd0da26ef70394e3 = L.marker(
#                 [50.0534233, 19.9543024],
#                 {}
#             ).addTo(map_54c1c0ca058e3d3df3563783fc82c85d);
#
#
#             var icon_05dbf258860f06145bff99db1fef449b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7dd2a5ae91feb4ffbd0da26ef70394e3.setIcon(icon_05dbf258860f06145bff99db1fef449b);
#
#
#         var popup_e33c214e186adf9c3e8dfab90144bf2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b37bc97ae9f1066888f49f3f9c36251f = $(`&lt;div id=&quot;html_b37bc97ae9f1066888f49f3f9c36251f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galeria Kazimierz&lt;/div&gt;`)[0];
#                 popup_e33c214e186adf9c3e8dfab90144bf2f.setContent(html_b37bc97ae9f1066888f49f3f9c36251f);
#
#
#
#         marker_7dd2a5ae91feb4ffbd0da26ef70394e3.bindPopup(popup_e33c214e186adf9c3e8dfab90144bf2f)
#         ;
#
#
#
#
#             var marker_ca3280c669a76f196a884d192224d3ad = L.marker(
#                 [50.0675936, 19.946146666336773],
#                 {}
#             ).addTo(map_54c1c0ca058e3d3df3563783fc82c85d);
#
#
#             var icon_9a14fc4d9d95b7e6d8334105724bf4b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca3280c669a76f196a884d192224d3ad.setIcon(icon_9a14fc4d9d95b7e6d8334105724bf4b5);
#
#
#         var popup_6fbd0e86377ff7e46c11d537aa177db1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c984e27a0fba35e5b1f4e48358c36535 = $(`&lt;div id=&quot;html_c984e27a0fba35e5b1f4e48358c36535&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galeria Krakowska&lt;/div&gt;`)[0];
#                 popup_6fbd0e86377ff7e46c11d537aa177db1.setContent(html_c984e27a0fba35e5b1f4e48358c36535);
#
#
#
#         marker_ca3280c669a76f196a884d192224d3ad.bindPopup(popup_6fbd0e86377ff7e46c11d537aa177db1)
#         ;
#
#
#
#
#             var marker_03d8e8fc4560ffbcc61e65b56e75c6ac = L.marker(
#                 [50.02797685, 19.950720762557644],
#                 {}
#             ).addTo(map_54c1c0ca058e3d3df3563783fc82c85d);
#
#
#             var icon_d475230b58e1b878da009dc3048d9923 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_03d8e8fc4560ffbcc61e65b56e75c6ac.setIcon(icon_d475230b58e1b878da009dc3048d9923);
#
#
#         var popup_3dfbcf7a3c80920e438a605a50a45308 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93ca76e69680df47803339c8878d1a9a = $(`&lt;div id=&quot;html_93ca76e69680df47803339c8878d1a9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bonarka City Center&lt;/div&gt;`)[0];
#                 popup_3dfbcf7a3c80920e438a605a50a45308.setContent(html_93ca76e69680df47803339c8878d1a9a);
#
#
#
#         marker_03d8e8fc4560ffbcc61e65b56e75c6ac.bindPopup(popup_3dfbcf7a3c80920e438a605a50a45308)
#         ;
#
#
#
#
#             var marker_424fb546d34ac065a77b5b2d038faa6a = L.marker(
#                 [50.0640656, 19.9990018],
#                 {}
#             ).addTo(map_54c1c0ca058e3d3df3563783fc82c85d);
#
#
#             var icon_3719a30d35663b521614f4d824f89551 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&qu

# %%
get_lat_long(street_workout)
plot_map(street_workout)
# Out:
# 100%|██████████| 6/6 [00:02<00:00,  2.06it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50fd1e770838bf8da46c09bcab7fcfd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50fd1e770838bf8da46c09bcab7fcfd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50fd1e770838bf8da46c09bcab7fcfd3 = L.map(
#                 &quot;map_50fd1e770838bf8da46c09bcab7fcfd3&quot;,
#                 {
#                     center: [50.06323178333333, 19.94114093679686],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_773c6c1d914334cf1f187832f4b5aac5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_50fd1e770838bf8da46c09bcab7fcfd3);
#
#
#             var marker_f2da85d8017ed0b5cbdc8def2b6f4cdf = L.marker(
#                 [50.0890279, 19.92101504305753],
#                 {}
#             ).addTo(map_50fd1e770838bf8da46c09bcab7fcfd3);
#
#
#             var icon_54ccd70ff271e90460224250245d235c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f2da85d8017ed0b5cbdc8def2b6f4cdf.setIcon(icon_54ccd70ff271e90460224250245d235c);
#
#
#         var popup_6f426d5fe461fb5a5f92d571991f8132 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2c79b5236aa9a3e6a3658d6b891fe0d = $(`&lt;div id=&quot;html_a2c79b5236aa9a3e6a3658d6b891fe0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ogródek jordanowski&lt;/div&gt;`)[0];
#                 popup_6f426d5fe461fb5a5f92d571991f8132.setContent(html_a2c79b5236aa9a3e6a3658d6b891fe0d);
#
#
#
#         marker_f2da85d8017ed0b5cbdc8def2b6f4cdf.bindPopup(popup_6f426d5fe461fb5a5f92d571991f8132)
#         ;
#
#
#
#
#             var marker_25f3651e52bd8762f57de223381a0612 = L.marker(
#                 [50.0066222, 19.9347788],
#                 {}
#             ).addTo(map_50fd1e770838bf8da46c09bcab7fcfd3);
#
#
#             var icon_b0643785a6e1884d40181c219ffe42f4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_25f3651e52bd8762f57de223381a0612.setIcon(icon_b0643785a6e1884d40181c219ffe42f4);
#
#
#         var popup_a4c508952813f749b5b3480269c1717f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db431e76905e86d4396a2b7ae6764acc = $(`&lt;div id=&quot;html_db431e76905e86d4396a2b7ae6764acc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ogródek jordanowski&lt;/div&gt;`)[0];
#                 popup_a4c508952813f749b5b3480269c1717f.setContent(html_db431e76905e86d4396a2b7ae6764acc);
#
#
#
#         marker_25f3651e52bd8762f57de223381a0612.bindPopup(popup_a4c508952813f749b5b3480269c1717f)
#         ;
#
#
#
#
#             var marker_6937361d469ffd7fdba8abb68d1b32df = L.marker(
#                 [50.08859245, 19.942636675130363],
#                 {}
#             ).addTo(map_50fd1e770838bf8da46c09bcab7fcfd3);
#
#
#             var icon_eec8a14382a87a384abdc891e3c04700 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6937361d469ffd7fdba8abb68d1b32df.setIcon(icon_eec8a14382a87a384abdc891e3c04700);
#
#
#         var popup_6df099c2a5175848c7e9a1727a44acdb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9aaf4b1f82545b26480d787975f7dd79 = $(`&lt;div id=&quot;html_9aaf4b1f82545b26480d787975f7dd79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ogródek jordanowski&lt;/div&gt;`)[0];
#                 popup_6df099c2a5175848c7e9a1727a44acdb.setContent(html_9aaf4b1f82545b26480d787975f7dd79);
#
#
#
#         marker_6937361d469ffd7fdba8abb68d1b32df.bindPopup(popup_6df099c2a5175848c7e9a1727a44acdb)
#         ;
#
#
#
#
#             var marker_08d75b84c92b33d7db5555a6af8161fa = L.marker(
#                 [50.0758346, 19.8883212],
#                 {}
#             ).addTo(map_50fd1e770838bf8da46c09bcab7fcfd3);
#
#
#             var icon_48a94040d6523b55477b9a027666a703 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&

# %%
get_lat_long(tax_administration_chamber)
plot_map(tax_administration_chamber)
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  2.03it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b3fc325f1f6319d431d71043ca3b5a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b3fc325f1f6319d431d71043ca3b5a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b3fc325f1f6319d431d71043ca3b5a4 = L.map(
#                 &quot;map_8b3fc325f1f6319d431d71043ca3b5a4&quot;,
#                 {
#                     center: [50.057175487500004, 19.932107339857993],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43d9f9fb4368ca0f6645bb885da5733f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8b3fc325f1f6319d431d71043ca3b5a4);
#
#
#             var marker_486166b84fb5efc0a41204fe3aa25854 = L.marker(
#                 [50.06082585, 19.934763691635865],
#                 {}
#             ).addTo(map_8b3fc325f1f6319d431d71043ca3b5a4);
#
#
#             var icon_3624f682ac0f28ea2b0a52fda413bf85 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_486166b84fb5efc0a41204fe3aa25854.setIcon(icon_3624f682ac0f28ea2b0a52fda413bf85);
#
#
#         var popup_3edc48818d53f7fbba38556b84da3f94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2622e1300044be31aa9bb7024263d5dc = $(`&lt;div id=&quot;html_2622e1300044be31aa9bb7024263d5dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Izba Administracji Skarbowej w Krakowie&lt;/div&gt;`)[0];
#                 popup_3edc48818d53f7fbba38556b84da3f94.setContent(html_2622e1300044be31aa9bb7024263d5dc);
#
#
#
#         marker_486166b84fb5efc0a41204fe3aa25854.bindPopup(popup_3edc48818d53f7fbba38556b84da3f94)
#         ;
#
#
#
#
#             var marker_0a14951a970f5b180db28c205ecbc432 = L.marker(
#                 [50.0317599, 19.9385454],
#                 {}
#             ).addTo(map_8b3fc325f1f6319d431d71043ca3b5a4);
#
#
#             var icon_52ac85c9b0f43f6affc69bf734529058 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0a14951a970f5b180db28c205ecbc432.setIcon(icon_52ac85c9b0f43f6affc69bf734529058);
#
#
#         var popup_4df202a0f37731651eafbcdc7373fa3f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5301313f1280311fe977393abedb367b = $(`&lt;div id=&quot;html_5301313f1280311fe977393abedb367b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Izba Administracji Skarbowej w Krakowie&lt;/div&gt;`)[0];
#                 popup_4df202a0f37731651eafbcdc7373fa3f.setContent(html_5301313f1280311fe977393abedb367b);
#
#
#
#         marker_0a14951a970f5b180db28c205ecbc432.bindPopup(popup_4df202a0f37731651eafbcdc7373fa3f)
#         ;
#
#
#
#
#             var marker_e7912cf1afbd7797413c6e867c00fcb2 = L.marker(
#                 [50.0575174, 19.9267],
#                 {}
#             ).addTo(map_8b3fc325f1f6319d431d71043ca3b5a4);
#
#
#             var icon_090e04ca9e3804e3e0f6721d134432c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e7912cf1afbd7797413c6e867c00fcb2.setIcon(icon_090e04ca9e3804e3e0f6721d134432c2);
#
#
#         var popup_7f55b286370d4ed2bc69f976b4443638 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26cb0561a1b9b78e70f996b99e3e51c6 = $(`&lt;div id=&quot;html_26cb0561a1b9b78e70f996b99e3e51c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Izba Administracji Skarbowej w Krakowie&lt;/div&gt;`)[0];
#                 popup_7f55b286370d4ed2bc69f976b4443638.setContent(html_26cb0561a1b9b78e70f996b99e3e51c6);
#
#
#
#         marker_e7912cf1afbd7797413c6e867c00fcb2.bindPopup(popup_7f55b286370d4ed2bc69f976b4443638)
#         ;
#
#
#
#
#             var marker_b4203a466e1855352ac5d1a829c6a5bb = L.marker(
#                 [50.0785988, 19.928420267796113],
#                 {}
#             ).addTo(map_8b3fc325f1f6319d431d71043ca3b5a4);
#
#
#             var icon_022347baf0c246ba2381ffa0e5986090 =

# %%
get_lat_long(tax_office)
plot_map(tax_office)
# Out:
# 100%|██████████| 6/6 [00:02<00:00,  2.04it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a20c29781815323b73d2f195036da029 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a20c29781815323b73d2f195036da029&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a20c29781815323b73d2f195036da029 = L.map(
#                 &quot;map_a20c29781815323b73d2f195036da029&quot;,
#                 {
#                     center: [50.069066541666665, 19.960510618629502],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_509de6092eef80451ee6a4d407bcff18 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a20c29781815323b73d2f195036da029);
#
#
#             var marker_143a70e6396a17c6c7852bd61e8252ba = L.marker(
#                 [50.1044526, 20.011668756330685],
#                 {}
#             ).addTo(map_a20c29781815323b73d2f195036da029);
#
#
#             var icon_17bf1f8b06ac621c9c026f8180826228 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_143a70e6396a17c6c7852bd61e8252ba.setIcon(icon_17bf1f8b06ac621c9c026f8180826228);
#
#
#         var popup_b5faea85329757904bdb8ccdfbaf5e8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_248513dc177913693d3a9af574c5c752 = $(`&lt;div id=&quot;html_248513dc177913693d3a9af574c5c752&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Małopolski Urząd Skarbowy w Krakowie&lt;/div&gt;`)[0];
#                 popup_b5faea85329757904bdb8ccdfbaf5e8c.setContent(html_248513dc177913693d3a9af574c5c752);
#
#
#
#         marker_143a70e6396a17c6c7852bd61e8252ba.bindPopup(popup_b5faea85329757904bdb8ccdfbaf5e8c)
#         ;
#
#
#
#
#             var marker_db1faf7c69a64edca898a75919438219 = L.marker(
#                 [50.08492885, 19.931430599115654],
#                 {}
#             ).addTo(map_a20c29781815323b73d2f195036da029);
#
#
#             var icon_c1db01c52fe3d8fc7644dd2a912c187f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_db1faf7c69a64edca898a75919438219.setIcon(icon_c1db01c52fe3d8fc7644dd2a912c187f);
#
#
#         var popup_59513687339638b7891b3ce2d6c3a75d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3f249e51e7d783ab776a2f78d2e10a0 = $(`&lt;div id=&quot;html_f3f249e51e7d783ab776a2f78d2e10a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Drugi Urząd Skarbowy Kraków&lt;/div&gt;`)[0];
#                 popup_59513687339638b7891b3ce2d6c3a75d.setContent(html_f3f249e51e7d783ab776a2f78d2e10a0);
#
#
#
#         marker_db1faf7c69a64edca898a75919438219.bindPopup(popup_59513687339638b7891b3ce2d6c3a75d)
#         ;
#
#
#
#
#             var marker_c9d906df4d9c4989ed361d19dad8b106 = L.marker(
#                 [50.1044526, 20.011668756330685],
#                 {}
#             ).addTo(map_a20c29781815323b73d2f195036da029);
#
#
#             var icon_c7420f7d4651f7a56c7ec456a1f21e02 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c9d906df4d9c4989ed361d19dad8b106.setIcon(icon_c7420f7d4651f7a56c7ec456a1f21e02);
#
#
#         var popup_e336613255b1df884c898f2184cd4a13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3975c1e2e64e99515859c3871418f62b = $(`&lt;div id=&quot;html_3975c1e2e64e99515859c3871418f62b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Małopolski Urząd Skarbowy w Krakowie&lt;/div&gt;`)[0];
#                 popup_e336613255b1df884c898f2184cd4a13.setContent(html_3975c1e2e64e99515859c3871418f62b);
#
#
#
#         marker_c9d906df4d9c4989ed361d19dad8b106.bindPopup(popup_e336613255b1df884c898f2184cd4a13)
#         ;
#
#
#
#
#             var marker_fb442a2eab93c62c6037ad47c0281103 = L.marker(
#                 [50.0331959, 19.9319668],
#                 {}
#             ).addTo(map_a20c29781815323b73d2f195036da029);
#
#
#             var icon_938f515ab31ce2ddb9f2aba1c6969633 = L.Awes

# %%
get_lat_long(technical_college)
plot_map(technical_college)
# Out:
# 100%|██████████| 29/29 [00:14<00:00,  2.01it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d13bebe1df146c2a0cdd6cd0973b130d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d13bebe1df146c2a0cdd6cd0973b130d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d13bebe1df146c2a0cdd6cd0973b130d = L.map(
#                 &quot;map_d13bebe1df146c2a0cdd6cd0973b130d&quot;,
#                 {
#                     center: [50.06322557413793, 19.968581303905054],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ef6635735760da5e9da5e079edab85d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d13bebe1df146c2a0cdd6cd0973b130d);
#
#
#             var marker_bf6d62b0da3daca94747d58514341b61 = L.marker(
#                 [50.076432499999996, 19.89326122957683],
#                 {}
#             ).addTo(map_d13bebe1df146c2a0cdd6cd0973b130d);
#
#
#             var icon_ed6be68a8a920066b95a2f2ff0f0eca7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bf6d62b0da3daca94747d58514341b61.setIcon(icon_ed6be68a8a920066b95a2f2ff0f0eca7);
#
#
#         var popup_ca44241d7c05d189a6f46a402b3a8bc6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bd054d5584ec5291950a27b9944ce87 = $(`&lt;div id=&quot;html_1bd054d5584ec5291950a27b9944ce87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Technikum Budowlane nr 1 Zespół Szkół Budowlanych nr 1&lt;/div&gt;`)[0];
#                 popup_ca44241d7c05d189a6f46a402b3a8bc6.setContent(html_1bd054d5584ec5291950a27b9944ce87);
#
#
#
#         marker_bf6d62b0da3daca94747d58514341b61.bindPopup(popup_ca44241d7c05d189a6f46a402b3a8bc6)
#         ;
#
#
#
#
#             var marker_fd75790f3a2a17610a7e24f1b6da62fd = L.marker(
#                 [50.0634871, 19.9296629],
#                 {}
#             ).addTo(map_d13bebe1df146c2a0cdd6cd0973b130d);
#
#
#             var icon_c559252b7215f34952caf37cd950259f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fd75790f3a2a17610a7e24f1b6da62fd.setIcon(icon_c559252b7215f34952caf37cd950259f);
#
#
#         var popup_d48c7d1816c0ea75adf0068ff13b0e1b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6326d95a8f4ca75f1081bc513e89edfc = $(`&lt;div id=&quot;html_6326d95a8f4ca75f1081bc513e89edfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Technikum Chemiczne i Ochrony Środowiska nr 3 Zespół Szkół Chemicznych&lt;/div&gt;`)[0];
#                 popup_d48c7d1816c0ea75adf0068ff13b0e1b.setContent(html_6326d95a8f4ca75f1081bc513e89edfc);
#
#
#
#         marker_fd75790f3a2a17610a7e24f1b6da62fd.bindPopup(popup_d48c7d1816c0ea75adf0068ff13b0e1b)
#         ;
#
#
#
#
#             var marker_c13a7e6fde8573f29a09b92d3beac968 = L.marker(
#                 [50.046420100000006, 19.922216683554048],
#                 {}
#             ).addTo(map_d13bebe1df146c2a0cdd6cd0973b130d);
#
#
#             var icon_bf6c60535ae9e7f7563005e96124c4de = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c13a7e6fde8573f29a09b92d3beac968.setIcon(icon_bf6c60535ae9e7f7563005e96124c4de);
#
#
#         var popup_baf9806506d248eb005bd4958a8271b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_253fbf5caa93f8da409aba8d457c9d14 = $(`&lt;div id=&quot;html_253fbf5caa93f8da409aba8d457c9d14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Technikum Łączności nr 14 Zespół Szkół Łączności&lt;/div&gt;`)[0];
#                 popup_baf9806506d248eb005bd4958a8271b2.setContent(html_253fbf5caa93f8da409aba8d457c9d14);
#
#
#
#         marker_c13a7e6fde8573f29a09b92d3beac968.bindPopup(popup_baf9806506d248eb005bd4958a8271b2)
#         ;
#
#
#
#
#             var marker_d9fd36160d555449d89e48088f51a7b1 = L.marker(
#                 [50.0774231, 20.02490496967878],
#                 {}
#             ).addTo(map_d13bebe1df146c2a0cdd6cd097

# %%
get_lat_long(vocational_school)
plot_map(vocational_school)
# Out:
# 100%|██████████| 30/30 [00:14<00:00,  2.01it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c5ea576aacc28fc46c6889a4b8e44ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c5ea576aacc28fc46c6889a4b8e44ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c5ea576aacc28fc46c6889a4b8e44ad = L.map(
#                 &quot;map_8c5ea576aacc28fc46c6889a4b8e44ad&quot;,
#                 {
#                     center: [50.064592226666655, 19.974851436048993],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6ffbab3b5e9b089993e93789c55f773 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8c5ea576aacc28fc46c6889a4b8e44ad);
#
#
#             var marker_971186c098f320e01667aa979c23b797 = L.marker(
#                 [50.076432499999996, 19.89326122957683],
#                 {}
#             ).addTo(map_8c5ea576aacc28fc46c6889a4b8e44ad);
#
#
#             var icon_7703fbb125deede5816bf8bd6b15db05 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_971186c098f320e01667aa979c23b797.setIcon(icon_7703fbb125deede5816bf8bd6b15db05);
#
#
#         var popup_9a45c8b56664e129d41e29fa7bcc5ec1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7bf7bbb54a43b956d6f28d78d2a563c = $(`&lt;div id=&quot;html_d7bf7bbb54a43b956d6f28d78d2a563c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Branżowa Szkoła I Stopnia nr 1 Zespół Szkół Budowlanych nr 1&lt;/div&gt;`)[0];
#                 popup_9a45c8b56664e129d41e29fa7bcc5ec1.setContent(html_d7bf7bbb54a43b956d6f28d78d2a563c);
#
#
#
#         marker_971186c098f320e01667aa979c23b797.bindPopup(popup_9a45c8b56664e129d41e29fa7bcc5ec1)
#         ;
#
#
#
#
#             var marker_f8ea51a9a9391b40f76046238bf8a8b3 = L.marker(
#                 [50.0431287, 19.9486552],
#                 {}
#             ).addTo(map_8c5ea576aacc28fc46c6889a4b8e44ad);
#
#
#             var icon_a952d1de17d4b71e9d6811389529d61c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f8ea51a9a9391b40f76046238bf8a8b3.setIcon(icon_a952d1de17d4b71e9d6811389529d61c);
#
#
#         var popup_d5a1c290daee75afe216377a7f8066f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a70748498831ed040982f85f1492dd99 = $(`&lt;div id=&quot;html_a70748498831ed040982f85f1492dd99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Branżowa Szkoła I Stopnia nr 10 Zespół Szkół Gastronomicznych nr 2&lt;/div&gt;`)[0];
#                 popup_d5a1c290daee75afe216377a7f8066f6.setContent(html_a70748498831ed040982f85f1492dd99);
#
#
#
#         marker_f8ea51a9a9391b40f76046238bf8a8b3.bindPopup(popup_d5a1c290daee75afe216377a7f8066f6)
#         ;
#
#
#
#
#             var marker_cfc6df59bd26fa182662c5a81b5854c5 = L.marker(
#                 [50.0839238, 20.0308351],
#                 {}
#             ).addTo(map_8c5ea576aacc28fc46c6889a4b8e44ad);
#
#
#             var icon_9d4a2b031f0377aacf70dfdfe0798c28 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cfc6df59bd26fa182662c5a81b5854c5.setIcon(icon_9d4a2b031f0377aacf70dfdfe0798c28);
#
#
#         var popup_084b958cf98a94b8c28586009f6ffd4a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0651677e3199b692b4129bb29a5d7f22 = $(`&lt;div id=&quot;html_0651677e3199b692b4129bb29a5d7f22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Branżowa Szkoła I Stopnia nr 11 Zespół Szkół Gastronomicznych nr 1&lt;/div&gt;`)[0];
#                 popup_084b958cf98a94b8c28586009f6ffd4a.setContent(html_0651677e3199b692b4129bb29a5d7f22);
#
#
#
#         marker_cfc6df59bd26fa182662c5a81b5854c5.bindPopup(popup_084b958cf98a94b8c28586009f6ffd4a)
#         ;
#
#
#
#
#             var marker_f01c0c49090019a411496928ccc2373a = L.marker(
#                 [50.046420100000006, 19.922216683554048],
#                 {}
#             ).addTo(map_8c5ea576aacc

# %%
get_lat_long(zabka)
plot_map(zabka)
# Out:
# 100%|██████████| 374/374 [03:06<00:00,  2.00it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddfab590c18f75fe7393a4206012b2a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddfab590c18f75fe7393a4206012b2a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddfab590c18f75fe7393a4206012b2a5 = L.map(
#                 &quot;map_ddfab590c18f75fe7393a4206012b2a5&quot;,
#                 {
#                     center: [50.05396946149729, 19.949166420335484],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e789c838f87e5c6a0aa5cae66adaabe8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ddfab590c18f75fe7393a4206012b2a5);
#
#
#             var marker_92ea8adfb8214cc047fc15006f1724f7 = L.marker(
#                 [50.0492468, 19.9592908],
#                 {}
#             ).addTo(map_ddfab590c18f75fe7393a4206012b2a5);
#
#
#             var icon_61f291993638b79129199c8d6d539921 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_92ea8adfb8214cc047fc15006f1724f7.setIcon(icon_61f291993638b79129199c8d6d539921);
#
#
#         var popup_5bd30778a0660f046f0edb8c9093b33a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44410e54c2729ad68c917ddb1e3c0e81 = $(`&lt;div id=&quot;html_44410e54c2729ad68c917ddb1e3c0e81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Żabka&lt;/div&gt;`)[0];
#                 popup_5bd30778a0660f046f0edb8c9093b33a.setContent(html_44410e54c2729ad68c917ddb1e3c0e81);
#
#
#
#         marker_92ea8adfb8214cc047fc15006f1724f7.bindPopup(popup_5bd30778a0660f046f0edb8c9093b33a)
#         ;
#
#
#
#
#             var marker_f50b639fe2fd29beef9de9578722644f = L.marker(
#                 [50.0471843, 19.955646],
#                 {}
#             ).addTo(map_ddfab590c18f75fe7393a4206012b2a5);
#
#
#             var icon_6350a0f4abdbd07d85a762d1fc6f3a53 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f50b639fe2fd29beef9de9578722644f.setIcon(icon_6350a0f4abdbd07d85a762d1fc6f3a53);
#
#
#         var popup_6c0174ae581abd1910b8d7293621bad4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0c4037829759568a913fe688d14ecfb = $(`&lt;div id=&quot;html_b0c4037829759568a913fe688d14ecfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Żabka&lt;/div&gt;`)[0];
#                 popup_6c0174ae581abd1910b8d7293621bad4.setContent(html_b0c4037829759568a913fe688d14ecfb);
#
#
#
#         marker_f50b639fe2fd29beef9de9578722644f.bindPopup(popup_6c0174ae581abd1910b8d7293621bad4)
#         ;
#
#
#
#
#             var marker_e29d7b00a3c59ca476fc0d12494809d4 = L.marker(
#                 [50.0461516, 19.9548848],
#                 {}
#             ).addTo(map_ddfab590c18f75fe7393a4206012b2a5);
#
#
#             var icon_7e4ac8f13208302f112594a0d3f81d26 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e29d7b00a3c59ca476fc0d12494809d4.setIcon(icon_7e4ac8f13208302f112594a0d3f81d26);
#
#
#         var popup_d239f783e766586ccf6a104d81909407 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9ef8de4becbb1bdc5f9e9bd926ba6aa = $(`&lt;div id=&quot;html_a9ef8de4becbb1bdc5f9e9bd926ba6aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Żabka&lt;/div&gt;`)[0];
#                 popup_d239f783e766586ccf6a104d81909407.setContent(html_a9ef8de4becbb1bdc5f9e9bd926ba6aa);
#
#
#
#         marker_e29d7b00a3c59ca476fc0d12494809d4.bindPopup(popup_d239f783e766586ccf6a104d81909407)
#         ;
#
#
#
#
#             var marker_c7821c81787d110140e55fcb9a84dc77 = L.marker(
#                 [50.0583068, 19.951382],
#                 {}
#             ).addTo(map_ddfab590c18f75fe7393a4206012b2a5);
#
#
#             var icon_e4f453373f38e6ef503a437c19adc441 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;inf

# %%
# Saving the dataframes with the new latitude and longitude columns to excel files
airport.to_excel('cleaned_data/geo_airport.xlsx')
chapels.to_excel('cleaned_data/geo_chapels.xlsx')
city_center.to_excel('cleaned_data/geo_city_center.xlsx')
emergency_room.to_excel('cleaned_data/geo_emergency_room.xlsx')
grocery_store.to_excel('cleaned_data/geo_grocery_store.xlsx')
gym.to_excel('cleaned_data/geo_gym.xlsx')
high_school.to_excel('cleaned_data/geo_high_school.xlsx')
hospital.to_excel('cleaned_data/geo_hospital.xlsx')
park.to_excel('cleaned_data/geo_park.xlsx')
pharmacy.to_excel('cleaned_data/geo_pharmacy.xlsx')
primary_care_units.to_excel('cleaned_data/geo_primary_care_units.xlsx')
primary_school.to_excel('cleaned_data/geo_primary_school.xlsx')
river.to_excel('cleaned_data/geo_river.xlsx')
roman_catholic_church.to_excel('cleaned_data/geo_roman_catholic_church.xlsx')
shopping_center.to_excel('cleaned_data/geo_shopping_center.xlsx')
technical_college.to_excel('cleaned_data/geo_technical_college.xlsx')
vocational_school.to_excel('cleaned_data/geo_vocational_school.xlsx')
zabka.to_excel('cleaned_data/geo_zabka.xlsx')
police_station.to_excel('cleaned_data/geo_police_station.xlsx')
custody_penitentiary.to_excel('cleaned_data/geo_custody_penitentiary.xlsx')
rossmann.to_excel('cleaned_data/geo_rossmann.xlsx')
tax_office.to_excel('cleaned_data/geo_tax_offices.xlsx')
tax_administration_chamber.to_excel('cleaned_data/geo_tax_administration_chambers.xlsx')
street_workout.to_excel('cleaned_data/geo_street_workouts.xlsx')
rope_park.to_excel('cleaned_data/geo_rope_parks.xlsx')
orlik_soccer_field.to_excel('cleaned_data/geo_orlik_soccer_fields.xlsx')
natural_swimming_pool.to_excel('cleaned_data/geo_natural_swimming_pools.xlsx')
museum.to_excel('cleaned_data/geo_museums.xlsx')
municipal_police_department.to_excel('cleaned_data/geo_municipal_police_departments.xlsx')
indoor_swimming_pool.to_excel('cleaned_data/geo_indoor_swimming_pool.xlsx')
horseback_riding_center.to_excel('cleaned_data/geo_horseback_riding_center.xlsx')
football_stadium.to_excel('cleaned_data/geo_football_stadiums.xlsx')
district_court.to_excel('cleaned_data/geo_district_court.xlsx')
cinema.to_excel('cleaned_data/geo_cinemas.xlsx')
